# %%
import os
from typing import List

import chromadb
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction, SentenceTransformerEmbeddingFunction
from dotenv import load_dotenv
from openai import OpenAI
import torch

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Test the influence of new chunking method on response generation
# We hope that, by having smaller chunks, the response generation will be better because less superfluous information is provided

# %%
# First get the Embedding Function and ChromaDB collection
# DOCUMENTS MUST HAVE BEEN ADDED TO THE CHROMA IN PREVIOUS NOTEBOOK

#model_name = "camembert-base"
#model_name = "dangvantuan/sentence-camembert-base"
model_name = "text-embedding-ada-002"

match model_name:
    case "text-embedding-ada-002":
        OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
        emb_func = OpenAIEmbeddingFunction(
                        api_key=OPENAI_API_KEY,
                        model_name="text-embedding-ada-002"
                    )

    case other:
        emb_func = SentenceTransformerEmbeddingFunction(
            model_name=model_name,
            device="cuda" if torch.cuda.is_available() else "cpu")


chroma_client = chromadb.PersistentClient(path=os.path.join("./ChromaDB", model_name))

# %% [markdown]
# ### Test retrieval manually

# %%
# Choose a collection name
collection_name = "chunked-pages-v1"
#collection_name = "ladrome-pages-json-v1-Markdown"
# Choose a query
query = "Comment fonctionne la médiathèque ?"
# choose the number of results
n_results = 10
# choose whether or not results are printed
print_results = True

collection = chroma_client.get_or_create_collection(
    collection_name,
    metadata={"hnsw:space": "cosine"},
    embedding_function=emb_func)

result = collection.query(
    query_texts=query,
    n_results=n_results,
)

if print_results:
    for rd, id in zip(result["documents"][0], result["ids"][0]):
        print(f"---------{id}---------")
        print(rd)
# Out:
# Add of existing embedding ID: 10511_0
# Add of existing embedding ID: 10516_0
# Add of existing embedding ID: 10516_1
# Add of existing embedding ID: 10516_2
# Add of existing embedding ID: 10516_3
# Add of existing embedding ID: 10516_4
# Add of existing embedding ID: 10520_0
# Add of existing embedding ID: 10520_1
# Add of existing embedding ID: 10520_2
# Add of existing embedding ID: 10520_3
# Add of existing embedding ID: 10520_4
# Add of existing embedding ID: 10520_5
# Add of existing embedding ID: 10522_0
# Add of existing embedding ID: 10524_0
# Add of existing embedding ID: 10526_0
# Add of existing embedding ID: 10533_0
# Add of existing embedding ID: 10537_0
# Add of existing embedding ID: 10542_0
# Add of existing embedding ID: 10542_1
# Add of existing embedding ID: 10565_0
# Add of existing embedding ID: 10565_1
# Add of existing embedding ID: 10565_2
# Add of existing embedding ID: 10565_3
# Add of existing embedding ID: 10565_4
# Add of existing embedding ID: 10692_0
# Add of existing embedding ID: 10694_0
# Add of existing embedding ID: 10696_0
# Add of existing embedding ID: 10698_0
# Add of existing embedding ID: 10700_0
# Add of existing embedding ID: 10708_0
# Add of existing embedding ID: 10708_1
# Add of existing embedding ID: 10708_2
# Add of existing embedding ID: 10710_0
# Add of existing embedding ID: 10712_0
# Add of existing embedding ID: 10714_0
# Add of existing embedding ID: 10718_0
# Add of existing embedding ID: 10720_0
# Add of existing embedding ID: 10722_0
# Add of existing embedding ID: 10728_0
# Add of existing embedding ID: 10730_0
# Add of existing embedding ID: 10732_0
# Add of existing embedding ID: 10734_0
# Add of existing embedding ID: 10738_0
# Add of existing embedding ID: 10745_0
# Add of existing embedding ID: 10757_0
# Add of existing embedding ID: 10759_0
# Add of existing embedding ID: 10761_0
# Add of existing embedding ID: 10763_0
# Add of existing embedding ID: 10763_1
# Add of existing embedding ID: 10763_2
# Add of existing embedding ID: 10763_3
# Add of existing embedding ID: 10765_0
# Add of existing embedding ID: 10765_1
# Add of existing embedding ID: 10765_2
# Add of existing embedding ID: 10765_3
# Add of existing embedding ID: 10767_0
# Add of existing embedding ID: 10769_0
# Add of existing embedding ID: 10771_0
# Add of existing embedding ID: 10771_1
# Add of existing embedding ID: 10771_2
# Add of existing embedding ID: 10771_3
# Add of existing embedding ID: 10777_0
# Add of existing embedding ID: 10779_0
# Add of existing embedding ID: 10779_1
# Add of existing embedding ID: 10779_2
# Add of existing embedding ID: 10781_1
# Add of existing embedding ID: 10781_2
# Add of existing embedding ID: 10781_3
# Add of existing embedding ID: 10781_4
# Add of existing embedding ID: 10781_5
# Add of existing embedding ID: 10781_6
# Add of existing embedding ID: 10783_0
# Add of existing embedding ID: 10783_1
# Add of existing embedding ID: 10783_2
# Add of existing embedding ID: 10783_3
# Add of existing embedding ID: 10783_4
# Add of existing embedding ID: 10787_0
# Add of existing embedding ID: 10787_1
# Add of existing embedding ID: 10787_2
# Add of existing embedding ID: 10789_0
# Add of existing embedding ID: 10789_1
# Add of existing embedding ID: 10789_2
# Add of existing embedding ID: 10789_3
# Add of existing embedding ID: 10789_4
# Add of existing embedding ID: 10791_0
# Add of existing embedding ID: 10791_1
# Add of existing embedding ID: 10791_2
# Add of existing embedding ID: 10791_3
# Add of existing embedding ID: 10791_4
# Add of existing embedding ID: 10791_5
# Add of existing embedding ID: 10793_0
# Add of existing embedding ID: 10793_1
# Add of existing embedding ID: 10793_2
# Add of existing embedding ID: 10793_3
# Add of existing embedding ID: 10797_0
# Add of existing embedding ID: 10797_1
# Add of existing embedding ID: 10799_0
# Add of existing embedding ID: 10799_1
# Add of existing embedding ID: 10868_0
# Add of existing embedding ID: 10868_1
# Add of existing embedding ID: 10870_0
# Add of existing embedding ID: 10872_0
# Add of existing embedding ID: 10874_0
# Add of existing embedding ID: 10876_1
# Add of existing embedding ID: 10899_0
# Add of existing embedding ID: 10901_0
# Add of existing embedding ID: 10909_0
# Add of existing embedding ID: 10918_0
# Add of existing embedding ID: 10920_0
# Add of existing embedding ID: 10920_1
# Add of existing embedding ID: 10920_2
# Add of existing embedding ID: 10920_3
# Add of existing embedding ID: 10922_0
# Add of existing embedding ID: 10922_1
# Add of existing embedding ID: 10936_0
# Add of existing embedding ID: 10938_0
# Add of existing embedding ID: 10940_0
# Add of existing embedding ID: 10942_0
# Add of existing embedding ID: 10956_0
# Add of existing embedding ID: 10958_0
# Add of existing embedding ID: 10958_1
# Add of existing embedding ID: 10958_2
# Add of existing embedding ID: 10958_3
# Add of existing embedding ID: 10958_4
# Add of existing embedding ID: 10958_5
# Add of existing embedding ID: 10958_6
# Add of existing embedding ID: 10962_0
# Add of existing embedding ID: 10968_0
# Add of existing embedding ID: 10970_0
# Add of existing embedding ID: 10972_0
# Add of existing embedding ID: 567239_5
# Add of existing embedding ID: 573222_0
# Add of existing embedding ID: 573222_1
# Add of existing embedding ID: 574603_0
# Add of existing embedding ID: 574603_1
# Add of existing embedding ID: 580011_0
# Add of existing embedding ID: 580074_0
# Add of existing embedding ID: 581681_0
# Add of existing embedding ID: 581681_1
# Add of existing embedding ID: 581681_2
# Add of existing embedding ID: 581681_3
# Add of existing embedding ID: 581681_4
# Add of existing embedding ID: 581681_5
# Add of existing embedding ID: 581681_6
# Add of existing embedding ID: 581681_7
# Add of existing embedding ID: 581681_8
# Add of existing embedding ID: 581681_9
# Add of existing embedding ID: 581813_0
# Add of existing embedding ID: 581817_0
# Add of existing embedding ID: 581817_1
# Add of existing embedding ID: 581817_2
# Add of existing embedding ID: 581830_0
# Add of existing embedding ID: 582072_0
# Add of existing embedding ID: 582076_0
# Add of existing embedding ID: 582076_1
# Add of existing embedding ID: 582076_2
# Add of existing embedding ID: 582076_3
# Add of existing embedding ID: 582085_0
# Add of existing embedding ID: 582085_1
# Add of existing embedding ID: 582085_2
# Add of existing embedding ID: 582085_3
# Add of existing embedding ID: 582085_4
# Add of existing embedding ID: 582085_5
# Add of existing embedding ID: 582085_6
# Add of existing embedding ID: 582085_7
# Add of existing embedding ID: 582101_0
# Add of existing embedding ID: 582176_1
# Add of existing embedding ID: 582176_2
# Add of existing embedding ID: 582176_3
# Add of existing embedding ID: 61260_0
# Add of existing embedding ID: 61492_0
# Add of existing embedding ID: 61494_0
# Add of existing embedding ID: 61497_0
# Add of existing embedding ID: 61497_1
# Add of existing embedding ID: 61500_0
# Add of existing embedding ID: 61504_0
# Add of existing embedding ID: 61507_0
# Add of existing embedding ID: 61510_0
# Add of existing embedding ID: 62538_0
# Add of existing embedding ID: 83595_0
# Add of existing embedding ID: 95161_0
# Add of existing embedding ID: 95161_2
# Add of existing embedding ID: 95161_3
# Add of existing embedding ID: 95161_4
# Add of existing embedding ID: 95161_5
# Add of existing embedding ID: 95161_6
# Add of existing embedding ID: 10511_0
# Add of existing embedding ID: 10516_0
# Add of existing embedding ID: 10516_1
# Add of existing embedding ID: 10516_2
# Add of existing embedding ID: 10516_3
# Add of existing embedding ID: 10516_4
# Add of existing embedding ID: 10520_0
# Add of existing embedding ID: 10520_1
# Add of existing embedding ID: 10520_2
# Add of existing embedding ID: 10520_3
# Add of existing embedding ID: 10520_4
# Add of existing embedding ID: 10520_5
# Add of existing embedding ID: 10522_0
# Add of existing embedding ID: 10524_0
# Add of existing embedding ID: 10526_0
# Add of existing embedding ID: 10533_0
# Add of existing embedding ID: 10537_0
# Add of existing embedding ID: 10542_0
# Add of existing embedding ID: 10542_1
# Add of existing embedding ID: 10565_0
# Add of existing embedding ID: 10565_1
# Add of existing embedding ID: 10565_2
# Add of existing embedding ID: 10565_3
# Add of existing embedding ID: 10565_4
# Add of existing embedding ID: 10692_0
# Add of existing embedding ID: 10694_0
# Add of existing embedding ID: 10696_0
# Add of existing embedding ID: 10698_0
# Add of existing embedding ID: 10700_0
# Add of existing embedding ID: 10708_0
# Add of existing embedding ID: 10708_1
# Add of existing embedding ID: 10708_2
# Add of existing embedding ID: 10710_0
# Add of existing embedding ID: 10712_0
# Add of existing embedding ID: 10714_0
# Add of existing embedding ID: 10718_0
# Add of existing embedding ID: 10720_0
# Add of existing embedding ID: 10722_0
# Add of existing embedding ID: 10728_0
# Add of existing embedding ID: 10730_0
# Add of existing embedding ID: 10732_0
# Add of existing embedding ID: 10734_0
# Add of existing embedding ID: 10738_0
# Add of existing embedding ID: 10745_0
# Add of existing embedding ID: 10757_0
# Add of existing embedding ID: 10759_0
# Add of existing embedding ID: 10761_0
# Add of existing embedding ID: 10763_0
# Add of existing embedding ID: 10763_1
# Add of existing embedding ID: 10763_2
# Add of existing embedding ID: 10763_3
# Add of existing embedding ID: 10765_0
# Add of existing embedding ID: 10765_1
# Add of existing embedding ID: 10765_2
# Add of existing embedding ID: 10765_3
# Add of existing embedding ID: 10767_0
# Add of existing embedding ID: 10769_0
# Add of existing embedding ID: 10771_0
# Add of existing embedding ID: 10771_1
# Add of existing embedding ID: 10771_2
# Add of existing embedding ID: 10771_3
# Add of existing embedding ID: 10777_0
# Add of existing embedding ID: 10779_0
# Add of existing embedding ID: 10779_1
# Add of existing embedding ID: 10779_2
# Add of existing embedding ID: 10781_1
# Add of existing embedding ID: 10781_2
# Add of existing embedding ID: 10781_3
# Add of existing embedding ID: 10781_4
# Add of existing embedding ID: 10781_5
# Add of existing embedding ID: 10781_6
# Add of existing embedding ID: 10783_0
# Add of existing embedding ID: 10783_1
# Add of existing embedding ID: 10783_2
# Add of existing embedding ID: 10783_3
# Add of existing embedding ID: 10783_4
# Add of existing embedding ID: 10787_0
# Add of existing embedding ID: 10787_1
# Add of existing embedding ID: 10787_2
# Add of existing embedding ID: 10789_0
# Add of existing embedding ID: 10789_1
# Add of existing embedding ID: 10789_2
# Add of existing embedding ID: 10789_3
# Add of existing embedding ID: 10789_4
# Add of existing embedding ID: 10791_0
# Add of existing embedding ID: 10791_1
# Add of existing embedding ID: 10791_2
# Add of existing embedding ID: 10791_3
# Add of existing embedding ID: 10791_4
# Add of existing embedding ID: 10791_5
# Add of existing embedding ID: 10793_0
# Add of existing embedding ID: 10793_1
# Add of existing embedding ID: 10793_2
# Add of existing embedding ID: 10793_3
# Add of existing embedding ID: 10797_0
# Add of existing embedding ID: 10797_1
# Add of existing embedding ID: 10799_0
# Add of existing embedding ID: 10799_1
# Add of existing embedding ID: 10868_0
# Add of existing embedding ID: 10868_1
# Add of existing embedding ID: 10870_0
# Add of existing embedding ID: 10872_0
# Add of existing embedding ID: 10874_0
# Add of existing embedding ID: 10876_1
# Add of existing embedding ID: 10899_0
# Add of existing embedding ID: 10901_0
# Add of existing embedding ID: 10909_0
# Add of existing embedding ID: 10918_0
# Add of existing embedding ID: 10920_0
# Add of existing embedding ID: 10920_1
# Add of existing embedding ID: 10920_2
# Add of existing embedding ID: 10920_3
# Add of existing embedding ID: 10922_0
# Add of existing embedding ID: 10922_1
# Add of existing embedding ID: 10936_0
# Add of existing embedding ID: 10938_0
# Add of existing embedding ID: 10940_0
# Add of existing embedding ID: 10942_0
# Add of existing embedding ID: 10956_0
# Add of existing embedding ID: 10958_0
# Add of existing embedding ID: 10958_1
# Add of existing embedding ID: 10958_2
# Add of existing embedding ID: 10958_3
# Add of existing embedding ID: 10958_4
# Add of existing embedding ID: 10958_5
# Add of existing embedding ID: 10958_6
# Add of existing embedding ID: 10962_0
# Add of existing embedding ID: 10968_0
# Add of existing embedding ID: 10970_0
# Add of existing embedding ID: 10972_0
# Add of existing embedding ID: 10974_0
# Add of existing embedding ID: 10989_0
# Add of existing embedding ID: 10995_0
# Add of existing embedding ID: 10997_0
# Add of existing embedding ID: 11010_0
# Add of existing embedding ID: 11012_0
# Add of existing embedding ID: 11014_0
# Add of existing embedding ID: 11016_0
# Add of existing embedding ID: 11018_0
# Add of existing embedding ID: 11051_0
# Add of existing embedding ID: 11057_0
# Add of existing embedding ID: 11061_0
# Add of existing embedding ID: 11080_0
# Add of existing embedding ID: 11082_0
# Add of existing embedding ID: 11225_0
# Add of existing embedding ID: 13093_0
# Add of existing embedding ID: 13093_10
# Add of existing embedding ID: 13093_6
# Add of existing embedding ID: 13093_7
# Add of existing embedding ID: 13093_8
# Add of existing embedding ID: 13093_9
# Add of existing embedding ID: 13584_0
# Add of existing embedding ID: 13590_0
# Add of existing embedding ID: 13604_0
# Add of existing embedding ID: 13604_1
# Add of existing embedding ID: 13604_2
# Add of existing embedding ID: 13618_0
# Add of existing embedding ID: 13627_0
# Add of existing embedding ID: 13718_0
# Add of existing embedding ID: 13718_1
# Add of existing embedding ID: 13718_2
# Add of existing embedding ID: 13718_3
# Add of existing embedding ID: 13718_4
# Add of existing embedding ID: 13724_0
# Add of existing embedding ID: 13727_0
# Add of existing embedding ID: 13736_0
# Add of existing embedding ID: 13812_0
# Add of existing embedding ID: 13814_0
# Add of existing embedding ID: 13820_0
# Add of existing embedding ID: 13830_0
# Add of existing embedding ID: 13832_0
# Add of existing embedding ID: 13832_1
# Add of existing embedding ID: 13834_0
# Add of existing embedding ID: 13874_0
# Add of existing embedding ID: 13874_1
# Add of existing embedding ID: 13874_2
# Add of existing embedding ID: 13927_0
# Add of existing embedding ID: 13929_0
# Add of existing embedding ID: 17218_0
# Add of existing embedding ID: 18873_0
# Add of existing embedding ID: 18881_0
# Add of existing embedding ID: 19076_0
# Add of existing embedding ID: 19078_0
# Add of existing embedding ID: 19080_0
# Add of existing embedding ID: 19080_1
# Add of existing embedding ID: 19080_2
# Add of existing embedding ID: 19094_0
# Add of existing embedding ID: 19110_0
# Add of existing embedding ID: 19110_1
# Add of existing embedding ID: 19110_2
# Add of existing embedding ID: 19110_3
# Add of existing embedding ID: 19110_4
# Add of existing embedding ID: 19112_0
# Add of existing embedding ID: 19152_0
# Add of existing embedding ID: 262450_0
# Add of existing embedding ID: 262453_0
# Add of existing embedding ID: 31094_0
# Add of existing embedding ID: 324859_0
# Add of existing embedding ID: 324886_0
# Add of existing embedding ID: 558957_0
# Add of existing embedding ID: 558960_0
# Add of existing embedding ID: 558960_1
# Add of existing embedding ID: 558960_2
# Add of existing embedding ID: 558968_0
# Add of existing embedding ID: 566648_0
# Add of existing embedding ID: 566648_1
# Add of existing embedding ID: 566648_2
# Add of existing embedding ID: 566648_3
# Add of existing embedding ID: 567070_0
# Add of existing embedding ID: 567072_0
# Add of existing embedding ID: 567239_0
# Add of existing embedding ID: 567239_1
# Add of existing embedding ID: 567239_2
# Add of existing embedding ID: 567239_3
# Add of existing embedding ID: 567239_4
# Add of existing embedding ID: 567239_5
# Add of existing embedding ID: 573222_0
# Add of existing embedding ID: 573222_1
# Add of existing embedding ID: 574603_0
# Add of existing embedding ID: 574603_1
# Add of existing embedding ID: 580011_0
# Add of existing embedding ID: 580074_0
# Add of existing embedding ID: 581681_0
# Add of existing embedding ID: 581681_1
# Add of existing embedding ID: 581681_2
# Add of existing embedding ID: 581681_3
# Add of existing embedding ID: 581681_4
# Add of existing embedding ID: 581681_5
# Add of existing embedding ID: 581681_6
# Add of existing embedding ID: 581681_7
# Add of existing embedding ID: 581681_8
# Add of existing embedding ID: 581681_9
# Add of existing embedding ID: 581813_0
# Add of existing embedding ID: 581817_0
# Add of existing embedding ID: 581817_1
# Add of existing embedding ID: 581817_2
# Add of existing embedding ID: 581830_0
# Add of existing embedding ID: 582072_0
# Add of existing embedding ID: 582076_0
# Add of existing embedding ID: 582076_1
# Add of existing embedding ID: 582076_2
# Add of existing embedding ID: 582076_3
# Add of existing embedding ID: 582085_0
# Add of existing embedding ID: 582085_1
# Add of existing embedding ID: 582085_2
# Add of existing embedding ID: 582085_3
# Add of existing embedding ID: 582085_4
# Add of existing embedding ID: 582085_5
# Add of existing embedding ID: 582085_6
# Add of existing embedding ID: 582085_7
# Add of existing embedding ID: 582101_0
# Add of existing embedding ID: 582176_1
# Add of existing embedding ID: 582176_2
# Add of existing embedding ID: 582176_3
# Add of existing embedding ID: 61260_0
# Add of existing embedding ID: 61492_0
# Add of existing embedding ID: 61494_0
# Add of existing embedding ID: 61497_0
# Add of existing embedding ID: 61497_1
# Add of existing embedding ID: 61500_0
# Add of existing embedding ID: 61504_0
# Add of existing embedding ID: 61507_0
# Add of existing embedding ID: 61510_0
# Add of existing embedding ID: 62538_0
# Add of existing embedding ID: 83595_0
# Add of existing embedding ID: 95161_0
# Add of existing embedding ID: 95161_2
# Add of existing embedding ID: 95161_3
# Add of existing embedding ID: 95161_4
# Add of existing embedding ID: 95161_5
# Add of existing embedding ID: 95161_6
# ---------10956_0---------
# Les médiathèques départementales
# Développer la lecture publique sur tout le territoire drômois est un engagement fort du Département. La Médiathèque départementale assure une double mission :
# - accueillir le public dans 5 médiathèques départementales à Valence, Crest, Die, Nyons et Saint Vallier
# - accompagner et soutenir 115 bibliothèques communales (formation, aide technique, prêt de documents, conseil aux élus…)
#
# ---------10771_1---------
# Vivre sa retraite dans la Drôme
# Les médiathèques et bibliothèques
# La lecture est un excellent exercice pour le cerveau. Quatre médiathèques départementales sont à votre disposition à Saint-Vallier, Crest, Die et Nyons. En plus des traditionnels livres et revues, elles proposent des documents qui, par leur forme ou leur contenu, peuvent être intéressants à consulter:
# - livres en gros caractères pour le confort de lecture;
# - livres audio
# - documents sur la vie quotidienne: santé, alimentation, droits et démarches…
# - CD de musique
# - DVD, films et documentaires Découvrez le site des médiathèques de la Drôme Pour les médiathèques intercommunales et bibliothèques municipales, renseignez-vous auprès de votre mairie.
# Pour plus d'informations:
# - médiathèques de la Drôme: https://mediatheque.ladrome.fr/
#
#
# ---------555850_1---------
# Un département proche, accessible et innovant
# Grands projets
#
# - Premier budget participatif: ouvert à tous les Drômois (dès 11 ans) qui souhaitent réaliser un projet pouvant profiter à tous.
# - Clic c’est numérique: développer les solutions numériques (prise de rendez-vous en ligne, SMS de rappel, mails, formulaires à télécharger ou à remplir en ligne) afin de faciliter les échanges entre les usagers et la collectivité.
# - Expérimenter et évaluer: avant de généraliser une nouvelle politique à l’ensemble du territoire, la collectivité procède à des expérimentations sur des secteurs et une période donnés. Durant cette phase, il s’agit de juger de l’efficacité de la démarche et des points d’amélioration à apporter. Une évaluation interne et externe permettra de faire évoluer et d’ajuster le service public départemental aux attentes des citoyens.
# Pour plus d'informations:
# - Premier budget participatif: https://www.ladrome.fr/je-mengage/budget-participatif/
#
#
# ---------581681_2---------
# Politique de cookies
# 3. Que sont les scripts?
# Un script est un élément de code utilisé pour que notre site web fonctionne correctement et de manière interactive. Ce code est exécuté sur notre serveur ou sur votre appareil.
#
# ---------547395_4---------
# Budget Participatif
# Comment participer ?
# Le dépôt de projets est ouvert en ligne du 10 janvier au 23 avril 2023. Rendez-vous sur la plateforme dédiée, après création d’un compte :budgetparticipatif.ladrome.fr
# Pour plus d'informations:
# - budgetparticipatif.ladrome.fr: https://budgetparticipatif.ladrome.fr/
#
#
# ---------547395_1---------
# Budget Participatif
# Qui peut participer ?
# Dès 11 ans, toute personne habitant en Drôme, ou étudiant drômois, seule ou en groupe (à but non lucratif), peut proposer une ou plusieurs idées.
#
# ---------480456_4---------
# Conditions générales d’utilisation de l’application mobile La Drôme
# Article 5. CONDITIONS FINANCIERES
# L’Application est proposée gratuitement aux Utilisateurs hors coûts d’abonnement auprès de l’opérateur de téléphonie mobile, hors coûts de connexion et d’accès au réseau Internet et hors surcoût éventuel facturé pour le chargement des données.
#
# ---------504961_2---------
# Etre connecté
# Le réseau WiFi Cigale
# Des bornes WiFi publiques ont été installées un peu partout sur le territoire avec le soutien du Département. Les Drômois peuvent ainsi se connecter gratuitement aux abords des offices de tourisme, des médiathèques, ou encore de certaines places publiques.
#
# ---------480456_10---------
# Conditions générales d’utilisation de l’application mobile La Drôme
# Article 11. DISPONIBILITE DE L’APPLICATION
# IDNext s’engage à faire ses meilleurs efforts pour sécuriser l’accès, la consultation et l’utilisation des Services de l’Application. L’Application est accessible 24 heures sur 24, 7 jours sur 7 sauf en cas de force majeure ou de survenance d’un évènement hors du contrôle du IDNext et sous réserve des éventuelles pannes et interventions de maintenance nécessaires au bon fonctionnement de l’Application. Les interventions de maintenance pourront être effectuées sans que les Utilisateurs aient été préalablement avertis.
#
# ---------13718_4---------
# Données personnelles
# Cookies tiers destinés à améliorer l’interactivité du site.
# Le site du Département de la Drôme s’appuie sur certains services proposés par des sites tiers. Il s’agit notamment :
# - Des boutons de partage (twitter et facebook)
# - Des vidéos diffusées sur le site (youtube)
# - De présentations animées (Slideshare/Calameo) Ces fonctionnalités utilisent des cookies tiers directement déposés par ces services. Lors de votre première visite sur ladrome.fr, un bandeau vous informe de la présence de ces cookies et vous invite à indiquer votre choix. Ils ne sont déposés que si vous les acceptez ou que vous poursuivez votre navigation sur le site en visitant une seconde page de ladrome.fr. Vous pouvez à tout moment vous informer et paramétrer vos cookies pour les accepter ou les refuser en vous rendant sur la page [[Gestion des cookies]](#cookies)présente en haut de chaque page du site. Vous pourrez indiquer votre préférence soit globalement pour le site, soit service par service.

# %% [markdown]
# ### Test response generation manually

# %%
# Choose a collection name
collection_name = "chunked-pages-v1"
#collection_name = "ladrome-pages-json-v1-Markdown"

COLLECTION = chroma_client.get_or_create_collection(
    collection_name,
    metadata={"hnsw:space": "cosine"},
    embedding_function=emb_func)

CLIENT = OpenAI()

def get_context(query:str, n_results=10):
    result = COLLECTION.query(
        query_texts=query,
        n_results=n_results,
    )
    return result["documents"][0]

def get_response(query:str, context:List[str]):

    context = "\n\n###\n".join(context)
    messages = [
        {"role": "system", "content": "Tu es un assistant utile répondant aux questions. Tu dois répondre de manière précise et concise à la question de l'utilisateur. Si tu peux résumer sous forme de bullet points, fais-le. Si tu dispose d'un lien permettant d'avoir plus d'information sur le sujet, propose-le. Si la réponse n'est pas dans le contexte, alors dis simplement 'Je suis désolé, je n'ai pas la réponse à votre question"},
        {"role": "user", "content": "- Tu vouvoies l'utilisateur lorsque tu réponds à sa question.\n- Tu travailles au Conseil départemental de la Drôme.\n- Tu dois afficher les liens au format markdown et hypertexte.\n- Tu dois répondre à la question de l'utilisateur en une seule réponse. Tu ne peux pas lui reposer de questions derrière."},
        {"role": "user", "content": f"Contexte :\n\n {context}"},
        {"role": "user", "content": f"Question : {query}"},
    ]
    response = CLIENT.chat.completions.create(
        model="gpt-3.5-turbo-16k",
        messages=messages,
        temperature=0,
    )
    return response.choices[0].message.content

# %%
import pandas as pd 
test_queries = pd.read_excel("./data/Test Semantics V2.xlsx")
test_queries.head(50)
# Out:
#                                              Question  \
# 0               Comment obtenir la carte top départ ?
# 1                             Comment obtenir l'APA ?
# 2   qui dois je contacter pour faire une demande d...
# 3             Comment devenir assistante maternelle ?
# 4                                   Contacter la mdph
# 5                         Où en est mon dossier AAH ?
# 6                 question autour des offres d'emploi
# 7   Où se situe le point d'accueil de la MDA à Mon...
# 8   J'ai perdu ma carte top départ, je fais commen...
# 9   Il y a un problème sur le route départementale...
# 10                  J'ai besoin d'aides alimentaires
# 11           demande d'agrément assistante maternelle
# 12                    Aide frais restauration cantine
# 13                        Demande de rendez vous Fhul
# 14                        Qui est élu à la culture ?
# 15                   J'ai été témoin de maltraitance
# 16                           Que faire ce week-end ?
# 17   Je souhaite obtenir une aide ménagère à domicile
# 18          Quelle est la stratégie départementale ?
# 19           Quelles sont les meilleures randonnées?
# 20  j'ai besoin de remplir une autorisation de voirie
# 21  Est-ce qu'il y a des travaux sur les routes en...
# 22                 c'est quoi l'actu au département ?
# 23  Comment faire une demande d'APA en établisseme...
# 24                   je dois faire garder mes enfants
# 25                           qui est l'élu au sport ?
# 26                 est-ce que j'ai le droit au FULH ?
# 27              quels sont les tiers lieux en drome ?
# 28           je voudrais consulter le plan foret bois
# 29           comment beneficier du pack retour emploi
# 30                          de quel cms je dépends ?
# 31                 De quel college mon fils dépend ?
# 32                     comment lire votre magazine ?
# 33                  comment fonctionne la médiathèque
# 34                                logo du département
# 35                                         info route
# 36            où je peux aller fair eune randonnée ?
# 37                  comment s'inscrire à Drôme Infos?
# 38                y a t-il des travaux sur valence ?
# 39                   Où se situe le cms de valence ?
# 40                 Où se situe la pmi à montélimar ?
# 41         y a t-il des offres d'emploi à pourvoir ?
# 42  est ce que les stations de la drome sont ouver...
#
#                               Réponse Wikit Semantics Statut de la réponse  \
# 0   Pour obtenir la carte Top Dép'Art, il y a deux...                   ok
# 1   Pour obtenir l'Allocation Personnalisée Autono...                   ko
# 2   Pour faire une demande d'APA (Allocation Perso...                   ok
# 3   Pour devenir assistante maternelle, vous devez...                   ko
# 4   contacter la mdph\nAssistant conversationnel L...                   ok
# 5   Je ne sais pas. Veuillez contacter la Maison D...                   ko
# 6   Je suis désolé, mais je ne peux pas répondre à...                   ko
# 7   Le point d'accueil de la MDA à Montélimar se s...                   ko
# 8   Si vous avez perdu votre carte Top Dép'Art, vo...                   ko
# 9   Je suis désolé, mais en tant qu'Assistant conv...                   ko
# 10  Je comprends que vous avez besoin d'aides alim...                   ko
# 11  Pour demander un agrément en tant qu'assistant...                   ko
# 12  Le Département de la Drôme propose différentes...                   ko
# 13  Je suis désolé, mais je ne peux pas prendre de...                   ko
# 14                                    Je ne sais pas                    ko
# 15  Si vous avez été témoin de maltraitance, il es...                  NaN
# 16                                    Je ne sais pas                    ko
# 17  Si vous avez de très faibles revenus, le Dépar...                   ok
# 18  La stratégie départementale fixe 4 objectifs m...                   ko
# 19                                    Je ne sais pas                   NaN
# 20  Pour remplir une autorisation de voirie, vous ...                  ok
# 21                                     Je ne sais pas                   ko
# 22                                    Je ne sais pas                    ko
# 23  Pour faire une demande d'Allocation Personnali...                   ok
# 24  Pour faire garder vos enfants, vous avez plusi...                   ko
# 25                                    Je ne sais pas                    ko
# 26  Je ne sais pas. Pour savoir si vous avez droit...                   ok
# 27  La Drôme compte une trentaine de tiers-lieux r...                   ok
# 28  Vous pouvez consulter le plan "Filière Forêt-B...                   ok
# 29  Pour bénéficier du "Pack retour à l'emploi" mi...                   ok
# 30  Je n'ai pas accès à votre localisation actuell...                   ok
# 31  Pour connaître le collège de rattachement de v...                   ko
# 32  Pour lire notre magazine "La Drôme - Le Magazi...                   ok
# 33  La médiathèque départementale de la Drôme fonc...                   ok
# 34  Le logo du Département de la Drôme est utilisé...                   ko
# 35  Je suis désolé, mais je n'ai pas accès aux inf...                   ok
# 36  Vous pouvez faire une randonnée dans de nombre...                   ko
# 37  Pour vous inscrire à Drôme Infos, vous pouvez ...                   ko
# 38  Je n'ai pas accès aux informations en temps ré...                   ko
# 39  Le Centre Médico-Social (CMS) de Valence se si...                   ko
# 40  La PMI (Protection Maternelle et Infantile) de...                   ko
# 41  Je n'ai pas accès en temps réel aux offres d'e...                   ko
# 42  Je n'ai pas encore la réponse mais j'apprends ...                   ko
#
#                                           Commentaire  \
# 0                                                 NaN
# 1   manque les liens pr télécharger les docs + inf...
# 2             est-il possible de faire lien mailto ?
# 3                le contenu est en cours de creation
# 4                                                 NaN
# 5   il faudrait que la réponse soit : Pour suivre ...
# 6   il faudrait répondre que pr postuler en ligne ...
# 7   il y a plusieurs adresses pr monté&limar donc ...
# 8   Aïe ! Tout n'est pas perdu !\nDéclarez rapidem...
# 9   mettre texte : "Je suis désolé, mais en tant q...
# 10     en fonction du statut, plusieurs aides existes
# 11        il faut que j'ajoute cette info sur le site
# 12                        cf réponse dans 1er tableau
# 13  réponse ici : https://www.ladrome.fr/wp-conten...
# 14  la réponse est dans les fiches élus : https://...
# 15  est-il possible de demander si maltraitance en...
# 16  la réponse est ici : https://www.ladrome.fr/ev...
# 17  préciser que c'est une aide pr les seniors, si...
# 18                        cf réponse dans 1er tableau
# 19                                                NaN
# 20  mettre lien vers page cerfa + lien vers platef...
# 21  mettre : Pour consulter l'état des routes, vou...
# 22  mettre : Les actualités du Département de la D...
# 23                    manque lien vers docs à remplir
# 24  ne pas mettre info assistants familials ni inf...
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  le lien n'est pas bon :  lien vers la carte : ...
# 32                                                NaN
# 33  si tu as du  temps, il faudrait mettre le lien...
# 34  texte ok mais il faudrai tplutot mettre le lie...
# 35                                                NaN
# 36  texte ok ajouter lien vers la page https://www...
# 37  ok pr le texte, just mettre le lien sur les te...
# 38  remttre le etxte info route "Pour accéder aux ...
# 39  le cms de valence n'est pas à cette adresse. P...
# 40  la réponse n'est correcte et en meme l'info n'...
# 41  Texte à mettre : Les offres d'emploi du Départ...
# 42  texte à mettre : Les horaires d'ouverture des ...
#
#                                     Commentaire Wikit
# 0                                                 NaN
# 1            Indicateur 4/5 sur le fond de la réponse
# 2                                                 NaN
# 3            Indicateur 3/5 sur le fond de la réponse
# 4                                                 NaN
# 5   Indicateur 3/5 sur le fond de la réponse ; par...
# 6   Indicateur 1/5 : vérifier si on a le lien vers...
# 7                                      Indicateur 1/5
# 8   Indicateur 5/5 : ce qui manque pour elle uniqu...
# 9                                     Indicateur 1/05
# 10                                    Indicateur 3/5
# 11                                    Indicateur 3/5
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34  Mathieu : envisager de mettre le lien de la pa...
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41  Mathieu : à nouveau, on a pas cette page dans ...
# 42                                                NaN

# %%
query_id = 24
query = test_queries.iloc[query_id]["Question"]
#query = "Où puis-je trouver l'adresse des MDA qui ne sont pas à Valence ?"

print_query = True
print_context = False

if print_query:
    print(query)
context = get_context(query, 10)
if print_context:
    print(context)

response = get_response(query, context)
print(response)
# Out:
# je dois faire garder mes enfants
# Voici les différents modes de garde disponibles pour vos enfants :
#
# - Assistant(e) maternel(le) : Vous pouvez choisir de confier vos enfants à un(e) assistant(e) maternel(le) agréé(e) par le Département de la Drôme. Ces professionnels ont suivi une formation obligatoire de 120 heures et une initiation aux gestes de premiers secours. Ils sont répartis sur le territoire de la Drôme. [Guide pratique – Sécurité chez l’assistant(e) maternel(le)](https://www.ladrome.fr/wp-content/uploads/2020/01/guide-scuit-chez-ass-mat-pour-les-ass-mat.pdf)
#
# - Établissements de placement : Si vous rencontrez des difficultés momentanées ou durables pour assumer la charge et l'éducation de vos enfants, vous pouvez envisager de les placer dans des établissements spécialisés tels que les villages d'enfants, les lieux de vie et d'accueil, les centres parentaux, les établissements sanitaires ou les établissements médico-sociaux d'éducation spéciale.
#
# - Protection Maternelle et Infantile (PMI) : Les centres de PMI sont des services de santé publique où vous pouvez recevoir des conseils et des soins médicaux pendant la grossesse et jusqu'aux 6 ans de votre enfant. Ils assurent également le contrôle médical, technique et financier des établissements d'accueil de la petite enfance et des assistantes maternelles. Vous pouvez vous renseigner auprès d'eux pour trouver le mode de garde qui vous convient le mieux.
#
# - Famille d'accueil (assistant familial) : Si vos enfants ont été temporairement séparés de votre famille par les services sociaux, vous pouvez envisager de les confier à un(e) assistant(e) familial(e). Ce métier est accessible sur diplôme d'État et rémunéré par un salaire. Vous devez obtenir un agrément délivré par le Département de la Drôme pour devenir assistant(e) familial(e).
#
# - Maison des Enfants : En cas de situation de danger pour vos enfants, la Maison Départementale des Enfants à Bourg-lès-Valence assure leur accueil et leur protection 365 jours par an et 24h/24. Ils y bénéficient d'une sécurité matérielle et physique avant d'être orientés vers une structure spécialisée, une famille d'accueil ou un foyer.
#
# - Relais Assistantes Maternelles (RAM) : Si vous recherchez une assistante maternelle, vous pouvez vous rendre dans les RAM où toutes les offres et demandes d'accueil sont centralisées. Vous y trouverez également des informations sur les prestations, les droits et les démarches à effectuer.
#
# N'hésitez pas à consulter les liens pour plus d'informations sur chaque mode de garde.

# %%
context
# Out:
# ["Les bons plans sports nature\nLes sports nature font partie de l’ADN de la Drôme ! Randonnée pédestre, VTT, course d’orientation, escalade, trail, canoë, spéléo, parapente… presque tous les sports de nature peuvent se pratiquer dans la Drôme. Le Département œuvre au quotidien, en partenariat avec de nombreux acteurs, pour aménager des sites de pratique, les entretenir et concilier les usages. La Drôme compte aujourd’hui \n- environ 6 000 km de sentiers de randonnée (pédestre, équestre, VTT) \n- 500 km d’itinéraires d’activités aquatiques (canoë kayak) \n- 7 stations hiver/été \n- 5 via ferrata \n- une vingtaine d’Espaces Sports Orientation \n- une cinquantaine de sites de vol libre \n- plus d’une centaine de sites d’escalade \n- une centaine de cavités de spéléologie… Retrouvez tous les parcours et sentiers sur l’application mobile La Drôme et laissez-vous guider ! Accès à l’extranet sport nature\nPour plus d'informations:\n- Accès à l’extranet sport nature: https://collaboratif.ladrome.fr\n\n",
#  "Le sport associatif\nGrâce aux associations présentes sur l’ensemble du territoire, il est possible de pratiquer la discipline de son choix à proximité de son lieu d’habitation. C’est dans cet optique de «sport pour tous» que le Département soutient plus de 200 associations sportives locales et 50 comités sportifs départementaux. Vous cherchez le sport et le club qui correspond le mieux à vos attentes? Rendez-vous sur drome.franceolympique.com\nPour plus d'informations:\n- drome.franceolympique.com: https://drome.franceolympique.com/trouver-un-club/\n\n",
#  "Vivre sa retraite dans la Drôme\nLe sport\nPratiquée de manière régulière et adaptée, une activité physique contribue à une bonne santé, tout en réduisant certains facteurs de risques (obésité, diabète, chutes…). Elle favorise la mémoire, la vigilance et la concentration et évite une diminution trop importante de la masse musculaire, due à l’avancée en âge. L’important est de pratiquer régulièrement : 30 à 60 minutes d’activité modérée chaque jour sont recommandées. Certaines activités quotidiennes comptent aussi pour du sport : prendre les escaliers, faire le ménage ou du jardinage, aller chercher le pain à pied…. Pour les sportifs plus confirmés, des activités comme la natation, la randonnée, le vélo, le yoga ou les exercices d’équilibres sont recommandées. Trouver les clubs proposant une offre d’activités physiques adaptées > https://drome.franceolympique.com\nPour plus d'informations:\n- https://drome.franceolympique.com: http://drome.franceolympique.com/\n\n",
#  'La démarche\nTourisme responsable\nNature authentique, paysages grandioses, activités de plein air, produits du terroir, circuits courts, mobilités douces, patrimoine historique et culturel… le tourisme constitue une activité essentielle pour l’économie locale et le maintien de services publics de proximité. Désormais, il se doit d’être plus responsable et adapté aux quatre saisons. Il sera ainsi mieux réparti sur les différents sites et plus serein. Les aménagements engagés pour les Sublimes Routes sont une des réponses du Département, correspondant à ce double enjeu de repenser le tourisme de demain tout en protégeant les espaces naturels remarquables, socles de la qualité de ce territoire, en concertation avec les habitants. #\n',
#  "Alpage de Font d’Urle (Vercors)\nA télécharger\nGuide découverte Le sentier du Karst Règlement intérieur de l’alpage de Font d’Urle Arrêté d’interdiction des chiens sur l’alpage de Font d’Urle Demande d’autorisation de manifestation sur l’alpage de Font d’Urle\nPour plus d'informations:\n- Guide découverte Le sentier du Karst: https://www.ladrome.fr/wp-content/uploads/2022/12/guide-decouverte-sentier-karst-2021.pdf\n- Règlement intérieur de l’alpage de Font d’Urle: https://www.ladrome.fr/wp-content/uploads/2023/01/reglement-interieur-alpage-font-urle.pdf\n- Arrêté d’interdiction des chiens sur l’alpage de Font d’Urle: https://www.ladrome.fr/wp-content/uploads/2023/01/arrete-interdiction-chiens-font-d-urle.pdf\n- Demande d’autorisation de manifestation sur l’alpage de Font d’Urle: https://www.ladrome.fr/wp-content/uploads/2020/12/4-6-4-2-1-dossier-autorisation-ft-urle.doc\n\n",
#  "Les projets en cours\nOù en est-on ?\nAvant de vous rendre sur les sublimes routes, pensez à vérifier les infos routes en cliquant ici.\nPour plus d'informations:\n- ici.: https://inforoutes.ladrome.fr\n\n"]
