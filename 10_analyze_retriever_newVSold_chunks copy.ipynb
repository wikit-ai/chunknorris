# %%
import json
import os

import chromadb
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction, SentenceTransformerEmbeddingFunction
from dotenv import load_dotenv
import tiktoken
import torch

#from src.SentenceTransformerEmbeddingFunction import SentenceTransformerEmbeddingFunction

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Prepare data embeddings
# ### Step 1 : Initialize a chromaDB

# %%
model_name = "dangvantuan/sentence-camembert-base"
#model_name = "text-embedding-ada-002"
# model_name = "sentence-transformers/all-MiniLM-L6-v2"

match model_name:
    case "text-embedding-ada-002":
        OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")
        emb_func = OpenAIEmbeddingFunction(
                        api_key=OPENAI_API_KEY,
                        model_name="text-embedding-ada-002"
                    )

    case other:
        emb_func = SentenceTransformerEmbeddingFunction(
            model_name=model_name,
            device="cuda" if torch.cuda.is_available() else "cpu")


chroma_client = chromadb.PersistentClient(path=os.path.join("./ChromaDB", model_name))

# %% [markdown]
# ### Step 2 : Add chunked documents to chroma

# %%
# create collection using folder's name
SOURCE_FOLDER = "../data\D26\ladrome-2023-12-22-page-chunked-v1"

collection = chroma_client.get_or_create_collection(
    os.path.basename(SOURCE_FOLDER),
    metadata={"hnsw:space": "cosine"},
    embedding_function=emb_func)

# %%
# if needed delete a collection
# chroma_client.delete_collection(os.path.basename(SOURCE_FOLDER))

# %%
# read the files
file_list = os.listdir(SOURCE_FOLDER)

def read_file(file):
    with open(os.path.join(SOURCE_FOLDER, file), "r") as f:
        return json.load(f)

data = [read_file(f) | {"file": f} for f in file_list]
data[0]
# Out:
# {'id': 'ladrome-page-10511-0.json',
#  'token_count': 657,
#  'word_count': 361,
#  'source_file': 'ladrome-page-10511.json',
#  'text': '# Un peu d’histoire\nSituée à mi-chemin entre l’Europe du nord et du sud, à la croisée des vallées du Rhône et de l’Isère, le département de la Drôme a toujours été une terre de passage, de brassage culturel et économique. La rivière Drôme, qui la transperce d’est en ouest, lui a donné son nom. Ses limites administratives ont été fixées en 1790 et en ont fait un département trait d’union entre Dauphiné et Provence. Rivière La Drôme – Crest © Francis Rey Terre d’asile pour les convertis à la Réforme, puis pour les Arméniens survivants du génocide de 1915, la Drôme s’engagea avec bravoure dans la Résistance contre l’occupant nazi. Le massif du Vercors garde la trace du martyre des maquisards et de la population civile perpétré lors des massacres de juillet 1944. La dernière moitié du 20esiècle a vu la Drôme développer ses infrastructures (autoroutes, gare TGV, aéroport) la rapprochant en temps et distance des métropoles françaises et capitales européennes. Une situation stratégique appréciée par de nombreuses entreprises. L’économie drômoise dispose d’un socle industriel solide et varié, proposant à la fois des secteurs traditionnels et des secteurs innovants, comme les technologies de l’énergie et du numérique. Un grand nombre de marques internationales ont implanté leur siège, un site de production ou de logistique dans la Drôme. Jars Céramistes – © Francis Rey JMD Vallon – © Claire Matras Département pionnier du bio en France, la Drôme cultive un capital agricole et viti-vinicole haut de gamme (nougat de Montélimar, huile de Nyons, truffe noire du Tricastin, vins de l’Hermitage et Côtes-du-Rhône, clairette de Die, ravioles du Royans, picodon, lavande fine…) que des chefs étoilés comme Anne-Sophie Pic ( Valence) subliment avec passion. Riche d’un patrimoine historique, culturel et naturel particulièrement varié, la Drôme est une destination touristique 4 saisons appréciée de petits et grands, notamment pour ses activités de sports de nature. Parmi les sites remarquables, on citera le château de Grignan (marquise de Sévigné), le Palais Idéal du facteur Cheval (Hauterives) et la forêt de Saoû. Forêt de Saoû – © Claire Matras Palais Idéal du facteur Cheval – © Claire Matras Château de Grignan – © Francis Rey\n',
#  'file': 'ladrome-page-10511-0.json'}

# %%
# Get an estimate of the total number of token (for cost estimation)
tokeniser = tiktoken.get_encoding("cl100k_base")

n_tokens = sum([len(tokeniser.encode(d["text"])) for d in data])
print("Amount of tokens :", n_tokens)
cost = round(n_tokens/1000*0.0001, 2)
print("Cost using ADAv2 : ", cost, "$")
if cost > 1:
    print("WARNING, BEWARE OF THE COST")
# Out:
# Amount of tokens : 115489
# Cost using ADAv2 :  0.01 $

# %%
# Build lists to add to chroma
def truncate_text(text, max_tokens_length=8192):
    encoded_text = tokeniser.encode(text)
    return tokeniser.decode(encoded_text[:max_tokens_length])

documents = [truncate_text(d["text"]) for d in data]
metadatas = [{k:v for k,v in d.items() if k in ["chunk_id", "source_file"]} for d in data]
ids = [d["file"] for d in data]

collection.add(
    documents=documents,
    metadatas=metadatas,
    ids=ids,
)

# %% [markdown]
# ### Step 3 : add old version of chunks in another collection

# %%
# create collection using folder's name
SOURCE_FOLDER = "../data\D26\ladrome-2023-12-22-md"

collection = chroma_client.get_or_create_collection(
    os.path.basename(SOURCE_FOLDER),
    metadata={"hnsw:space": "cosine"},
    embedding_function=emb_func)

# %%
# Delete collection if needed
# chroma_client.delete_collection(os.path.basename(SOURCE_FOLDER))

# %%
# read the files
file_list = os.listdir(SOURCE_FOLDER)

def read_file(file):
    with open(os.path.join(SOURCE_FOLDER, file), "r") as f:
        return json.load(f)

data = [read_file(f) | {"file": f} for f in file_list]
data[0]
# Out:
# {'@context': 'https://wikit.ai',
#  '@type': 'Document',
#  'identifier': 'ladrome:page:10511',
#  'name': 'un-peu-dhistoire',
#  'title': 'Un peu d’histoire',
#  'source': 'La Drôme.fr',
#  'url': 'https://www.ladrome.fr/mon-departement/la-drome/un-peu-dhistoire/',
#  'dateCreated': '2019-01-07T16:11:49',
#  'dateModified': '2023-09-20T10:49:08',
#  'fileFormat': 'text/markdown',
#  'hasPart': [{'@type': 'DocumentChunk',
#    'title': 'Un peu d’histoire',
#    'text': 'Un peu d’histoire\n\nSituée à mi-chemin entre l’Europe du nord et du sud, à la croisée des vallées du Rhône et de l’Isère, le département de la Drôme a toujours été une terre de passage, de brassage culturel et économique.\n\nLa rivière Drôme, qui la transperce d’est en ouest, lui a donné son nom. Ses limites administratives ont été fixées en 1790 et en ont fait un département trait d’union entre Dauphiné et Provence.\n\n[![](https://www.ladrome.fr/wp-content/uploads/2023/09/riviere-drome-crest-rey-003.jpg)](https://www.ladrome.fr/wp-content/uploads/2023/09/riviere-drome-crest-rey-003.jpg)\n\nRivière La Drôme – Crest © Francis Rey\n\nTerre d’asile pour les convertis à la Réforme, puis pour les Arméniens survivants du génocide de 1915, la Drôme s’engagea avec bravoure dans la Résistance contre l’occupant nazi. Le massif du Vercors garde la trace du martyre des maquisards et de la population civile perpétré lors des massacres de juillet 1944.\n\nLa dernière moitié du 20e\xa0siècle a vu la Drôme développer ses infrastructures (autoroutes, gare TGV, aéroport) la rapprochant en temps et distance des métropoles françaises et capitales européennes. Une situation stratégique appréciée par de nombreuses entreprises.\n\nL’économie drômoise dispose d’un socle industriel solide et varié, proposant à la fois des secteurs traditionnels et des secteurs innovants, comme les technologies de l’énergie et du numérique. Un grand nombre de marques internationales ont implanté leur siège, un site de production ou de logistique dans la Drôme.\xa0\xa0\n\n[![](https://www.ladrome.fr/wp-content/uploads/2023/09/jars-rey-9.jpg)](https://www.ladrome.fr/wp-content/uploads/2023/09/jars-rey-9.jpg)\n\nJars Céramistes – © Francis Rey\n\n[![](https://www.ladrome.fr/wp-content/uploads/2023/09/pmdvallon.png)](https://www.ladrome.fr/wp-content/uploads/2023/09/pmdvallon.png)\n\nJMD Vallon – © Claire Matras\n\nDépartement pionnier du bio en France, la Drôme cultive un capital agricole et viti-vinicole haut de gamme (nougat de Montélimar, huile de Nyons, truffe noire du Tricastin, vins de l’Hermitage et Côtes-du-Rhône, clairette de Die, ravioles du Royans, picodon, lavande fine…) que des chefs étoilés comme Anne-Sophie Pic (\\*\\*\\* Valence) subliment avec passion.\n\nRiche d’un patrimoine historique, culturel et naturel particulièrement varié, la Drôme est une destination touristique 4 saisons appréciée de petits et grands, notamment pour ses activités de sports de nature. Parmi les sites remarquables, on citera le château de Grignan (marquise de Sévigné), le Palais Idéal du facteur Cheval (Hauterives) et la forêt de Saoû.\n\n[![](https://www.ladrome.fr/wp-content/uploads/2023/09/foret-saou-matras-004.jpg)](https://www.ladrome.fr/wp-content/uploads/2023/09/foret-saou-matras-004.jpg)\n\nForêt de Saoû – © Claire Matras\n\n[![](https://www.ladrome.fr/wp-content/uploads/2023/09/palais-idealmatras.jpg)](https://www.ladrome.fr/wp-content/uploads/2023/09/palais-idealmatras.jpg)\n\nPalais Idéal du facteur Cheval – © Claire Matras\n\n[![](https://www.ladrome.fr/wp-content/uploads/2019/12/chteau-grignan-lavande-2012-rey-54-1-1196x800.jpg)](https://www.ladrome.fr/wp-content/uploads/2019/12/chteau-grignan-lavande-2012-rey-54-1.jpg)\n\nChâteau de Grignan – © Francis Rey',
#    'pageStart': 1,
#    'pageEnd': 1}],
#  'file': 'ladrome-page-10511.json'}

# %%
# Get an estimate of the total number of token (for cost estimation)
tokeniser = tiktoken.get_encoding("cl100k_base")

n_tokens = sum([len(tokeniser.encode(d["hasPart"][0]["text"])) for d in data])
print("Amount of tokens :", n_tokens)
cost = round(n_tokens/1000*0.0001, 2)
print("Cost using ADAv2 : ", cost, "$")
if cost > 1:
    print("WARNING, BEWARE OF THE COST")
# Out:
# Amount of tokens : 111377
# Cost using ADAv2 :  0.01 $

# %%
def truncate_text(text, max_tokens_length=8192):
    encoded_text = tokeniser.encode(text)
    return tokeniser.decode(encoded_text[:max_tokens_length])

# Build lists to add to chroma
documents = [truncate_text(d["hasPart"][0]["text"]) for d in data]
metadatas = [{"source_file":d["file"]} for d in data]
ids = [d["file"] for d in data]

collection.add(
    documents=documents,
    metadatas=metadatas,
    ids=ids,
)

# %% [markdown]
# ## Try out the DB

# %%
# Choose a collection name
#collection_name = "ladrome-2023-12-22-page-chunked-v1"
collection_name = "ladrome-2023-12-22-md"
# Choose a query
query = "Adresse de la MDA de Valence ?"
# choose the number of results
n_results = 10
# choose whether or not results are printed
print_results = True

collection = chroma_client.get_or_create_collection(
    collection_name,
    metadata={"hnsw:space": "cosine"},
    embedding_function=emb_func)

result = collection.query(
    query_texts=query,
    n_results=n_results,
)

if print_results:
    for rd, id in zip(result["documents"][0], result["ids"][0]):
        print(f"---------{id}---------")
        print(rd)
# Out:
# ---------ladrome-page-10936.json---------
# La lutte contre la tuberculose
#
# Vous pensez avoir été en contact avec une personne atteinte de la tuberculose ?
#
# En cas de suspicion de symptômes, consultez le Centre de Lutte Anti-Tuberculeux (CLAT) de la Drôme.
#
# 13 avenue Maurice Faure
#
# BP 81132 – 26 011 Valence Cedex 9
#
# Tel 04 75 79 70 71
# ---------ladrome-page-11020.json---------
# Les stations de la Drôme
#
#
# ---------ladrome-page-10565.json---------
# Un département, des territoires
#
# Située au cœur du grand Sud-Est de la France, la Drôme est l’un des 12 départements de la Région Auvergne Rhône-Alpes.
#
# *   **Préfecture** : Valence
# *   **Sous-préfectures** : Die, Nyons
# *   **Villes de plus de 10 000 habitants** : Valence, Montélimar, Romans, Bourg-lès-Valence, Pierrelatte, Bourg de Péage
# *   **A savoir** : la Drôme est depuis toujours un département pionnier en agriculture bio, et le 1er département agricole d’Auvergne Rhône-Alpes
# *   **Particularité** : comme son nom l’indique, l’enclave des Papes (département du Vaucluse) est enchassée dans le territoire drômois
#
# De par sa structure historique, géographique et climatique, la Drôme offre une grande variété des paysages. On distingue cinq « pays ».
#
# ### Drôme des collines
#
# De l’ancienne province du Dauphiné, la Drôme septentrionale a hérité une certaine sobriété, nuancée par la rondeur et la douceur de ses paysages.
#
# **Patrimoine et sites remarquables** : le vignoble de l’Hermitage, le Palais Idéal du facteur Cheval à Hauterives, le musée international de la Chaussure à Romans.
#
# ### Plaine de Valence
#
# Vergers roses et blancs, champs jaune colza sur fond de contreforts bleus du Vercors, la plaine valentinoise offre le visage d’une campagne aux airs de citadine.
#
# Préfecture, pôle universitaire, cité gourmande : Valence s’épanouit au bord du Rhône, avec notamment l’Epervière, premier port fluvial de plaisance de France.
#
# **Patrimoine et sites remarquables** : kiosque Peynet, Maison des Têtes, cathédrale Saint-Appolinaire, parc Jouvet, musées des Beaux Arts, Centre du Patrimoine Arménien.
#
# ### Royans-Vercors
#
# Accessible par des routes souvent vertigineuses (Combe Laval), le massif du Vercors abrite une nature sauvage et une biodiversité exceptionnelle. Les stations de Font d’Urle et du col de Rousset offrent un cadre familial pour les activités de neige.
#
# **Plusieurs lieux de mémoire** évoquent la Résistance et la tragédie du maquis : le village martyr de Vassieux-en-Vercors « compagnon de la Libération », le musée départemental de la Résistance, la nécropole des Pionniers du Vercors, le mémorial national de la Résistance (col de La Chau), la grotte de la Luire.
#
# ### Vallée de la Drôme-Diois
#
# Façonnée par la rivière qui a donné son nom au département, la vallée s’étire du Vercors au Rhône.
#
# Son cours traverse le vignoble de la clairette de Die, frôle le massif et la forêt de Saoû (synclinal perché et Trois Becs), salue la tour de Crest (plus haut donjon de France) avant de rejoindre la réserve naturelle des Ramières.
#
# **Patrimoine et sites remarquables** : le Claps (Luc-en-Diois), la montagne du Glandasse, le musée du protestantisme dauphinois (Poët-Laval).
#
# ### Drôme provençale
#
# Des Baronnies à la vallée du Rhône, de Nyons à Grignan, la Drôme provençale revendique ses racines et traditions méditerranéennes.
#
# Lavande, oliviers, petit épeautre, vignobles des Côtes-du-Rhône, truffes noires du Tricastin, tilleul des Baronnies : la Drôme provençale se regarde, se respire, se savoure avec gourmandise.
#
# **Patrimoine et sites remarquables** : châteaux de Grignan (marquise de Sévigné), de Suze-la-Rousse (patrimoine viti-vinicole), des Adhémar à Montélimar (espace culturel), Ferme aux Crocodiles (Pierrelatte).
# ---------ladrome-page-567070.json---------
# Mentions légales – Autorisations de voirie
#
# #### Éditeur du site « autorisationsdevoirie.ladrome.fr »
#
# Département de la Drôme
# 26, avenue du Président Herriot
# 26 026 Valence Cedex 09
# Tel : 04 75 79 26 26
#
# #### Directrice de la Publication
#
#
# Marie-Pierre Mouton, présidente du Conseil départemental de la Drôme
#
# #### Directeur de la Rédaction
#
# Pôle Gestion du Domaine Public Routier
#
# #### Gestion, suivi et mise à jour du site
#
# Pôle Gestion du Domaine Public Routier
#
# #### Conception et réalisation
#
# ONTOMANTICS S.A.S
# ZAC des Aulnaies 959 rue de la Bergeresse 45 160 OLIVET
# Tel +33 (0)1 83 62 73 12
# Courriel contact@ontomantics.com
#
# #### Crédits photos
#
# Francis Rey, Direction de la communication – Département de la Drôme
#
# #### Hébergement du site
#
# Dosin – Département de la Drôme.
#
# #### Qualité des informations diffusées
#
# Nous nous efforçons d’offrir sur notre site web une information fiable, vérifiée et actualisée. Mais, malgré tout le soin que nous y apportons, des erreurs ou omissions peuvent subsister. Nous nous efforçons de corriger les erreurs qui nous sont signalées.
#
# #### Cookies
#
# Notre site collecte les cookies strictement nécessaires au fonctionnement du site
#
# #### Contact
#
# Direction des Déplacements Pôle Gestion du Domaine Public Routier – pegdp@ladrome.fr
# ---------ladrome-page-13093.json---------
# Mentions légales
#
# Éditeur du site
# ---------------
#
# ladrome.fr est édité par le Département de la Drôme
# Avenue du Président Herriot
# 26026 Valence Cédex 09
# Tel : 04 75 79 26 26
#
# Directrice de la Publication
# ----------------------------
#
# Marie-Pierre Mouton, présidente du Conseil départemental de la Drôme
#
# Directeur de la Rédaction
# -------------------------
#
# William Rabain, directeur de la Communication externe
#
# Gestion, suivi et mise à jour du site
# -------------------------------------
#
# Marie Drogue mdrogue@ladrome.fr
#
# Conception et réalisation
# -------------------------
#
# KYXAR
# 40 Bd de la Libération – 26100 Romans-sur-Isère
# info@kyxar.fr
#
# Crédits photos
# --------------
#
# Francis Rey, Claire Matras
#
# Hébergement du site
# --------------------
#
# W3LINE
# 10 ter Rue Pasteur
# 26 500 Bourg les Valence
# Tel :04 75 82 81 01
#
# Respect des droits d’auteur, quid de la loi de 57 ?
# ---------------------------------------------------
#
# Ce site est destiné à votre information. Vous disposez d’un droit d’utilisation, à des fins exclusivement personnelles et non commerciales, des informations qui y sont contenues.
# Vous n’êtes donc pas autorisé à modifier, distribuer, transmettre, diffuser, représenter, reproduire, publier, transférer ou vendre tout ou partie de ce site, tout document téléchargé à partir de ce site ou toutes listes de liens obtenues à partir de ce site, ni à créer des œuvres dérivées de ces documents ou listes de liens, sauf accord particulier et préalable conclu avec le Conseil Départemental de la Drôme.
#
# Tout lien avec le présent site doit faire l’objet d’un accord préalable du service communication.
#
# L’ensemble de ce site relève des législations française et internationale sur le droit d’auteur et la propriété intellectuelle. Tous les droits de reproduction sont réservés, y compris pour les documents iconographiques et photographiques. La reproduction de tout ou partie de ce site sur un support électronique quel qu’il soit est formellement interdite sauf autorisation expresse du directeur de la publication.
#
# La reproduction des textes de ce site sur support papier est autorisée, tout particulièrement dans le cadre pédagogique, sous réserve du respect des trois conditions suivantes :
#
# *   gratuité de la diffusion
# *   respect de l’intégrité des documents reproduits : pas de modification ni altération d’aucune sorte
# *   citation claire et lisible de la source sous la suivante [https://www.ladrome.fr](https://www.ladrome.fr/)
#
# Qualité des informations diffusées
# ----------------------------------
#
# Nous nous efforçons d’offrir sur notre site web une information fiable, vérifiée et actualisée. Mais, malgré tout le soin que nous y apportons, des erreurs ou omissions peuvent subsister. Nous nous efforçons de corriger les erreurs qui nous sont signalées.
#
# Adresses de courriel
# --------------------
#
# Les adresses de courriel des services du Conseil départemental de la Drôme ne sont données que dans un cadre strictement professionnel. Ces adresses ne doivent en aucun cas être utilisées pour des actions de publipostage électronique ou toutes autres utilisations non liées aux activités du Conseil Départemental de la Drôme.
#
# Contact
# --------
#
# Pour toute question relative aux mentions légales ou à la protection des données personnelles, pour signaler toutes erreurs, notamment celles relatives aux données personnelles ou pour modifier, rectifier ou supprimer ces données, les internautes doivent remplir le [formulaire de contact](https://www.ladrome.fr/je-contacte/)
# ---------ladrome-page-95161.json---------
# Marchés publics
#
# ### **Où trouver les annonces marchés publics du Département de la Drôme ?**
#
# Rendez-vous sur notre site [www.marcel26.fr](http://www.marcel26.fr/), qui répertorie la plupart des annonces marchés des acheteurs publics du territoire drômois (communes, syndicats…).
#
# ### **Les marchés publics en cours du Département de la Drôme**
#
# #### A télécharger
#
# [Programmation des marchés publics de la Drôme – Mise à jour juin 2023](https://www.ladrome.fr/sites/default/files/programmation-marches-publics-drome.pdf)
#
# [Nouveau guide rappelant les opportunités d’affaires qu’offre la commande publique](https://www.ladrome.fr/wp-content/uploads/2020/03/guidemarchespublicsweb.pdf)
#
# #### Le dossier de consultation des entreprises, ça vous parle ?
#
# Pour en savoir plus sur les marchés publics, vous pouvez consulter le site internet du ministère de l’économie : [www.economie.gouv.fr](https://www.economie.gouv.fr/daj/commande-publique)
#
# ### **Le service achats du Département**
#
# Il intervient pour toutes les procédures d’achats d’un montant supérieur à 40 000 € HT.
#
# Deux filières d’achat le composent : aménagements (bâtiments et déplacements) et achats transversaux (fournitures et services, prestations intellectuelles non liées à des opérations de travaux, maintenance…).
#
# #### Contacts
#
# *   pour des renseignements relatifs à des procédures en cours de consultation : [consultations-achats@ladrome.fr](mailto:consultations-achats@ladrome.fr)
# *   pour toute prise de contact non liée à une procédure en cours : [contactachats-fournisseurs@ladrome.fr](mailto:contactachats-fournisseurs@ladrome.fr)
#
# ### **La démarche achats responsables**
#
# Le Département s’est engagé dans une démarche d’achats responsables depuis plusieurs années, à travers l’utilisation de matériaux et de méthodes respectueuses de l’environnement en matière de travaux, de référentiels techniques en faveur du développement durable pour la construction de collèges et par l’intégration de clauses sociales dans les marchés.
#
# En effet, pour les marchés de travaux, des seuils ont été fixés au-delà desquels des clauses d’insertion doivent obligatoirement être intégrés dans les dossiers de consultation :
#
# *   90 000 € HT pour les marchés des bâtiments
# *   250 000 € HT pour les marchés des routes
#
# L’objectif est de faire en sorte que l’entreprise attributaire du marché réserve une partie des heures de travail que lui procure le marché à des personnes éloignées de l’emploi.
#
# Retrouvez les coordonnées du facilitateur dans les pièces des marchés concernés.
# ---------ladrome-page-10966.json---------
# Les châteaux de la Drôme
#
# Histoire et culture à Grignan, Suze-la-Rousse, Adhémar (Montélimar)
# ---------ladrome-page-567072.json---------
# Données personnelles – Autorisations de voirie
#
# Les données à caractère personnel recueillies sont nécessaires à l’instruction de votre demande par la direction des Déplacements du Département de La Drôme, sur « autorisationsdevoirie.ladrome.fr » En application du règlement général sur la protection des données personnelles (RGPD) – UE 2016/679 du 27/04/2016, nous vous communiquons ici les informations les concernant.
#
# **Base juridique du traitement**
#
# Le traitement est fondé sur la mission d’intérêt public dont est investi le Département de la Drôme.
#
# **Finalités du traitement :**
# Le présent traitement a pour objectif de vous permettre de créer votre compte sur « autorisationsdevoirie.ladrome.fr » en vue d’accéder aux services suivants :
# • l’instruction et le suivi de votre demande
# • la rédaction et la consultation de l’arrêté autorisant la demande
# • la gestion des contacts pour dialoguer, informer, comptabiliser, encaisser les redevances
# • l’historisation des demandes et des actes
# • le suivi statistique des demandes et des actes
#
# **Catégories de données collectées**
# • vos noms, prénom, profession,
# • votre e-mail, téléphone
#
# **Destinataires des données**
#
# Les personnels du Pôle Gestion du Domaine Public Routier départemental habilités à l’administration et la gestion de la plateforme.
#
# **Transferts des données hors UE**
#
# Les données concernées sont hébergées dans nos serveurs et ne font pas l’objet d’un transfert de données hors de l’Union européenne.
#
# **Durée de conservation des données**
#
# Les données de ce formulaire sont conservées jusqu’à la suppression du compte
#
# **Exercer vos droits sur vos données à caractère personnel**
#
# Conformément au cadre réglementaire en vigueur, notamment le règlement européen UE (2016/679) du 27 avril 2016, dans ses articles 15 à 22 et la loi Informatique et Libertés modifiée articles 49 à 56 vous disposez des droits d’accès à vos données, de rectification de vos données, de limitation du traitement, de vous opposer au traitement de vos données pour un motif d’intérêt légitime.
#
# **Modalités d’exercice de vos droits**
#
# Toute information relative à vos droits sur vos données personnelles ou toute demande liée à l’exercice de vos droits, peuvent être formulées :
# • soit par courriel sécurisé, accompagné d’une copie de votre titre d’identité à dpo@ladrome.fr
# • soit par voie postale, le demandeur adresse un courrier signé accompagné d’une copie de son titre d’identité à l’adresse suivante : Département de la Drôme Direction des Déplacements
# Pôle Gestion du Domaine Public Routier départemental A l’attention du délégué à la protection des données 26 avenue du Président Herriot 26 026 Valence Cedex 9
#
# Vous disposez également du droit, quand cela est rendu nécessaire, d’introduire une réclamation auprès de l’autorité de contrôle compétente, la Commission Nationale de l’Informatique et des Libertés (CNIL):
#
# soit par voie postale: Commission Nationale Informatique et Libertés 3, place Fontenoy – TSA 80 715 – 75 334 Paris cedex, soit par courriel sur www.cnil.fr
# ---------ladrome-page-10942.json---------
# Médecins : vivre et exercer dans la Drôme
#
# Vous êtes médecin et vous souhaitez vous installer dans la Drôme ? Contactez la mission Santé du Département de la Drôme.
#
# **Mission Santé**
# 04 75 79 69 86 – [contact mail](mailto:fmichalon@ladrome.fr)
# ---------ladrome-page-10956.json---------
# Les médiathèques départementales
#
# Développer la lecture publique sur tout le territoire drômois est un engagement fort du Département. La Médiathèque départementale assure une double mission :
#
# *   **accueillir** le public dans 5 médiathèques départementales à Valence, Crest, Die, Nyons et Saint Vallier
# *   **accompagner et soutenir** 115 bibliothèques communales (formation, aide technique, prêt de documents, conseil aux élus…)

# %% [markdown]
# ## Test with labeled dataset
# ### Step 1 : read dataset

# %%
import pandas as pd

# %%
dataset = pd.read_excel("../data/D26/D26_dataset_handmade.xlsx")
dataset["relevant_chunk_ids"] = dataset["relevant_chunk_ids"].str.split()
dataset.dropna(inplace=True, subset=["relevant_chunk_ids"])
dataset.head()
# Out:
#                                              queries  \
# 0  Combien de productions ont déjà bénéficié du f...
# 1  Je voudrais bénéficier de l'accueil familial. ...
# 2  Quels sont les horaires du musée départemental...
# 3  Quels sont les résultats de conformité du site...
# 4                    Qu'est ce que la cartoucherie ?
#
#                        queries as keywords  chunk_version  \
# 0  bénéficiare fond soutien œuvres animées            1.0
# 1                 contact acceuil familial            1.0
# 2           horaire musée de la résistance            1.0
# 3   résultats conformité acessibilité site            1.0
# 4                 explication cartoucherie            1.0
#
#              relevant_chunk_ids useful_links_available  \
# 0  [ladrome-page-573222-1.json]                    NaN
# 1   [ladrome-page-13929-0.json]                    NaN
# 2   [ladrome-page-10958-3.json]                    NaN
# 3  [ladrome-page-479533-2.json]                    NaN
# 4   [ladrome-page-10516-3.json]                    NaN
#
#                                          long answer  \
# 0  15 à 20 projet bénéficient d'une subvention ch...
# 1  Vous pouvez contacter Drôme Solidarités\n04 75...
# 2  Les horaires d'ouverture varient d'un mois à l...
# 3  L’audit de conformité au RGAA 4.1 réalisé par ...
# 4  Sous l’impulsion de Jacques-Rémy Girerd (studi...
#
#                                             keywords Unnamed: 7
# 0                                                 83        NaN
# 1  Drôme Solidarités 04 75 79 70 09 dromeseniorso...        NaN
# 2  avril :du mardi au dimanche, de 10h à 12h et d...        NaN
# 3                                             0.8958        NaN
# 4       pôle d’excellence régional de l’image animée        NaN

# %% [markdown]
# ### Step 2 : Test with new chunks

# %%
# Choose a collection name
collection_name = "ladrome-2023-12-22-page-chunked-v1"

# Query the DB with all queries
queries = dataset["queries"].tolist()
collection = chroma_client.get_or_create_collection(
    collection_name,
    metadata={"hnsw:space": "cosine"},
    embedding_function=emb_func)
n_results = collection.count() # get the results on the entire DB

print(f"The collection has {collection.count()} documents")

result = collection.query(
    query_texts=queries,
    n_results=n_results,
)
# Out:
# The collection has 361 documents

# %%
result_df = pd.DataFrame.from_dict(result)
result_df.drop(["embeddings", "uris", "data"], inplace=True, axis=1)
result_df["query"] = queries
result_df["label"] = dataset["relevant_chunk_ids"].tolist()
result_df.head(3)
# Out:
#                                                  ids  \
# 0  [ladrome-page-573222-1.json, ladrome-page-1096...
# 1  [ladrome-page-10759-0.json, ladrome-page-10765...
# 2  [ladrome-page-10958-0.json, ladrome-page-10958...
#
#                                            distances  \
# 0  [0.575617840095566, 0.6614375114440918, 0.7035...
# 1  [0.49739736318588257, 0.51413893699646, 0.5231...
# 2  [0.48037004470825195, 0.5899790525436401, 0.59...
#
#                                            metadatas  \
# 0  [{'source_file': 'ladrome-page-573222.json'}, ...
# 1  [{'source_file': 'ladrome-page-10759.json'}, {...
# 2  [{'source_file': 'ladrome-page-10958.json'}, {...
#
#                                            documents  \
# 0  [# Le cinéma d’animation dans la Drôme\n### Le...
# 1  [# L’adoption\nAdopter un enfant, c’est répond...
# 2  [# Le musée départemental de la Résistance du ...
#
#                                                query  \
# 0  Combien de productions ont déjà bénéficié du f...
# 1  Je voudrais bénéficier de l'accueil familial. ...
# 2  Quels sont les horaires du musée départemental...
#
#                           label
# 0  [ladrome-page-573222-1.json]
# 1   [ladrome-page-13929-0.json]
# 2   [ladrome-page-10958-3.json]

# %%
# Get the position of the labeled document in the results using metadatas
# best if rank closer to 0
def get_label_position(row):
    # get the source files, which are ordered by distance
    return row["ids"].index(row["label"][0])


result_df["label_rank"] = result_df.apply(get_label_position, axis=1)
result_df = result_df.sort_values(by="label_rank").reset_index()
# show the result
result_df[["query", "label_rank", "label"]].head(100)
# Out:
#                                                 query  label_rank  \
# 0   Combien de productions ont déjà bénéficié du f...           0
# 1        Où puis-je trouver les logo du département ?           0
# 2   Je voudrais me mettre au basket. Où puis-je tr...           0
# 3     Quelles sont les règles du buget participatif ?           0
# 4   Par quelles villes va passer la flamme olympiq...           0
# ..                                                ...         ...
# 74                        Ou en est mon dossier AAH ?          98
# 75              Quels sont les tiers lieux en drome ?         189
# 76               C'est quoi le CDJ ? A quoi ça sert ?         194
# 77  J'aimerai obtenir des information sur la situa...         225
# 78                          De quel cms je dépends ?          252
#
#                            label
# 0   [ladrome-page-573222-1.json]
# 1    [ladrome-page-62538-0.json]
# 2    [ladrome-page-11012-0.json]
# 3   [ladrome-page-547395-6.json]
# 4   [ladrome-page-567239-2.json]
# ..                           ...
# 74   [ladrome-page-10791-0.json]
# 75  [ladrome-page-504975-0.json]
# 76   [ladrome-page-11080-0.json]
# 77  [ladrome-page-582085-4.json]
# 78   [ladrome-page-19152-0.json]
#
# [79 rows x 3 columns]

# %%
# analyze result of the specific query id
query_id = 49 # the index of the dataframe above
topk = 10

record = result_df.iloc[query_id]
print(record["query"])
for i, (id, r) in enumerate(zip(record["ids"][:topk], record["documents"][:topk])):
    print(f"Chunk n°{i}--------------{id}------------------")
    print(r)
# Out:
# Comment puis-je obtenir la carte top dép'art ?
# Chunk n°0--------------ladrome-page-17218-5.json------------------
# # La carte Top Dép’Art
# ## Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr (pour plus d'informations : https://carte-topdepart.ladrome.fr/Accueil/)
# ### Où utiliser ma carte top dép’art ?
# Retrouvez sur la carte interactive (pour plus d'informations : https://carte-topdepart.ladrome.fr/Beneficiaires/Views/RechercheLocalisation_PartenaireV2.aspx) la liste des partenaires qui acceptent le paiement avec la carte Top Dép’art.
#
# Chunk n°1--------------ladrome-page-17218-0.json------------------
# # La carte Top Dép’Art
# Acheter un livre, payer sa licence de sport, visiter une exposition ou prendre des cours de théâtre, le Département délivre chaque année la carte « Top Dép’art », à tous les collégiens de la Drôme. ---
#
# Chunk n°2--------------ladrome-page-17218-3.json------------------
# # La carte Top Dép’Art
# ## Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr (pour plus d'informations : https://carte-topdepart.ladrome.fr/Accueil/)
# ### Qui peut bénéficier de la Top Dép’art ?
# La carte Top Dép’Art est destinée à tous les collégiens drômois scolarisés dans le public ou le privé, ainsi qu’aux collégiens scolarisés hors du département mais dont les représentants légaux résident dans la Drôme (pas de cumul avec le Pass’ Région délivré par la Région Auvergne-Rhône-Alpes). Sont également concernés les collégiens scolarisés dans les Etablissements Régionaux d’Enseignement Adapté (de la 6e à la 3e), les collégiens scolarisés en lycée professionnel en dehors de la Région Auvergne-Rhône-Alpes, ainsi que les élèves âgés de 10 à 16 ans inscrits dans un établissement pour la jeunesse handicapée tels que les IME et les ITEP, dont les représentants légaux résident dans la Drôme.
#
# Chunk n°3--------------ladrome-page-17218-6.json------------------
# # La carte Top Dép’Art
# ## Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr (pour plus d'informations : https://carte-topdepart.ladrome.fr/Accueil/)
# ### carte-topdepart.ladrome.fr
# Le sport, la culture et les loisirs à portée de clic. Le site permet de :
# - commander la carte
# - consulter le solde des crédits
# - consulter les partenaires Top Dép’Art
# - télécharger votre QR Code
# - déclarer le vol ou la perte de votre carte
# - envoyer un message à nos équipes si vous rencontrez une difficulté
# - ajouter un bénéficiaire sur votre compte (lorsque vous avez un autre enfant qui rentre au Collège)
#
# Chunk n°4--------------ladrome-page-17218-4.json------------------
# # La carte Top Dép’Art
# ## Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr (pour plus d'informations : https://carte-topdepart.ladrome.fr/Accueil/)
# ### Comment l’obtenir ?
#
# - pour les 6èmes, les nouveaux arrivants et les collégiens drômois n’ayant encore jamais eu de carte Top Dép’Art : elle est à commander gratuitement en créant votre compte sur notre site ou via notre application mobile « la Drôme »
# - pour les 5èmes, 4èmes et 3èmes qui ont déjà leur carte Top Dép’Art : leur établissement scolaire se charge de renouveler leurs droits pour l’année scolaire 2023/2024
#
# Chunk n°5--------------ladrome-page-17218-1.json------------------
# ## Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr
# ---
# Pour plus d'informations:
# - Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr: https://carte-topdepart.ladrome.fr/Accueil/
#
# Chunk n°6--------------ladrome-page-17218-7.json------------------
# # La carte Top Dép’Art
# ## Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr (pour plus d'informations : https://carte-topdepart.ladrome.fr/Accueil/)
# ### Devenir partenaire des collégiens de la Drôme
# Rejoignez dès maintenant le dispositif de la carte Top Dép’art et bénéficiez d’une visibilité accrue pour votre enseigne, votre club ou votre association. > Création de votre compte sur carte-topdepart.ladrome.fr (pour plus d'informations : https://carte-topdepart.ladrome.fr/Partenaires/Accueil.aspx?ReturnUrl=%2fPartenaires)
#
# Chunk n°7--------------ladrome-page-17218-8.json------------------
# # La carte Top Dép’Art
# ## Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr (pour plus d'informations : https://carte-topdepart.ladrome.fr/Accueil/)
# ### Plus d’informations :
# Consulter le règlement (pour plus d'informations : https://carte-topdepart.ladrome.fr/Accueil/Documents/Règlement Top Dép'Art.pdf) Accéder directement à l’espace collégien (pour plus d'informations : https://carte-topdepart.ladrome.fr/Beneficiaires/AccueilNonConnecte.aspx?ReturnUrl=%2fBeneficiaires) Consulter la FAQ collégien (pour plus d'informations : https://carte-topdepart.ladrome.fr/Beneficiaires/FAQ.aspx) Accéder directement à l’espace partenaire (pour plus d'informations : https://carte-topdepart.ladrome.fr/Partenaires/Accueil.aspx?ReturnUrl=%2fPartenaires) Consulter la FAQ partenaire (pour plus d'informations : https://carte-topdepart.ladrome.fr/Partenaires/FAQ.aspx) Accéder à l’espace établissement (pour plus d'informations : https://carte-topdepart.ladrome.fr/Etablissements/Connexion.aspx)
#
# Chunk n°8--------------ladrome-page-17218-2.json------------------
# # La carte Top Dép’Art
# ## Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr (pour plus d'informations : https://carte-topdepart.ladrome.fr/Accueil/)
# ### C’est quoi la carte Top Dép’Art ?
#
# - 20€ pour le sport (achat de matériel sportif, adhésion annuelle dans un club sportif, piscine, patinoire…)
# - 20€ pour la culture (livres, cinémas, cours de théâtre, musique…)
# - 25€ pour la pratique régulière du sport ou de la culture
# - 4 entrées gratuites pour le collégien et son accompagnant : – 1 entrée patrimoine : musée départemental de la Résistance de Vassieux, musée de la chaussure à Romans, châteaux de la Drôme, Auberge des Dauphins à Saoû… – 1 entrée spectacle vivant : Fêtes Nocturnes de Grignan, Comédie de Valence, Lux, le Train Théâtre… – 1 entrée ou activité sport nature : en hiver ou en été, dans les stations de la Drôme – 1 entrée sport professionnel : un match de l’un des 5 clubs sportifs « élite » de la Drôme
#
# Chunk n°9--------------ladrome-page-17218-9.json------------------
# # La carte Top Dép’Art
# ## Pour commander la carte Top Dép’Artcarte-topdepart.ladrome.fr (pour plus d'informations : https://carte-topdepart.ladrome.fr/Accueil/)
# ### Contact :
# Pour toute question : contactez le 0 800 711 362, appel gratuit du lundi au vendredi de 8h à 20h

# %%
# Store df in new variable for comparison later
result_new_chunks = result_df.copy()

# %% [markdown]
# ### Step 3: Test with old chunks

# %%
# Choose a collection name
collection_name = "ladrome-2023-12-22-md"

# Query the DB with all queries
queries = dataset["queries"].tolist()
collection = chroma_client.get_or_create_collection(
    collection_name, metadata={"hnsw:space": "cosine"},
    embedding_function=emb_func)

n_results = collection.count() # get the results on the entire DB

print(f"The collection has {collection.count()} documents")

result = collection.query(
    query_texts=queries,
    n_results=n_results,
)
# Out:
# The collection has 191 documents

# %%
result_df = pd.DataFrame.from_dict(result)
result_df.drop(["embeddings", "uris", "data"], inplace=True, axis=1)
result_df["query"] = queries
result_df["label"] = dataset["relevant_chunk_ids"].tolist()
result_df.head(3)
# Out:
#                                                  ids  \
# 0  [ladrome-page-10962.json, ladrome-page-10710.j...
# 1  [ladrome-page-10759.json, ladrome-page-13929.j...
# 2  [ladrome-page-10958.json, ladrome-page-10972.j...
#
#                                            distances  \
# 0  [0.6844645142555237, 0.6964281797409058, 0.759...
# 1  [0.49768853187561035, 0.5210072013881537, 0.55...
# 2  [0.5489376783370972, 0.7043828964233398, 0.717...
#
#                                            metadatas  \
# 0  [{'source_file': 'ladrome-page-10962.json'}, {...
# 1  [{'source_file': 'ladrome-page-10759.json'}, {...
# 2  [{'source_file': 'ladrome-page-10958.json'}, {...
#
#                                            documents  \
# 0  [Enseignements artistiques\n\nOutils majeurs d...
# 1  [L’adoption\n\nAdopter un enfant, c’est répond...
# 2  [Le musée départemental de la Résistance du Ve...
#
#                                                query  \
# 0  Combien de productions ont déjà bénéficié du f...
# 1  Je voudrais bénéficier de l'accueil familial. ...
# 2  Quels sont les horaires du musée départemental...
#
#                           label
# 0  [ladrome-page-573222-1.json]
# 1   [ladrome-page-13929-0.json]
# 2   [ladrome-page-10958-3.json]

# %%
# Get the position of the labeled document in the results using metadatas
# best if rank closer to 0
def get_label_position(row):
    label = row["label"][0].split("-")[2]
    label = "ladrome-page-" + label + ".json"
    # get the source files, which are ordered by distance
    return row["ids"].index(label)


result_df["label_rank"] = result_df.apply(get_label_position, axis=1)
result_df = result_df.sort_values(by="label_rank").reset_index()
# show the result
result_df[["query", "label_rank", "label"]].head(50)
# Out:
#                                                 query  label_rank  \
# 0   Je voudrais installer un monte escalier mais ç...           0
# 1   J'ai perdu ma carte top départ, je fais commen...           0
# 2   Où puis-je consulter les annonces des marchés ...           0
# 3   Par quelles villes va passer la flamme olympiq...           0
# 4   Je voudrais savoir si je suis éligible à la fi...           0
# 5            Où se déroulent les scéances publiques ?           0
# 6    Je souhaite obtenir une aide ménagère à domicile           0
# 7                   Mon père est violent avec ma mère           0
# 8   Ai-je le droit de proposer une idée pour le bu...           0
# 9           Nous voudrions faire une ballade en forêt           0
# 10  Quels sont les avantages proposés par la carte...           0
# 11        J'ai été témoin de maltraitance d'un enfant           0
# 12  Combien de temps dure la formation pour deveni...           0
# 13  J'aimerai avoir les tarifs du musée de la rési...           0
# 14  j'ai besoin de remplir une autorisation de voirie           0
# 15  Je voudrais me mettre au basket. Où puis-je tr...           0
# 16              Où trouver un assistante maternelle ?           0
# 17  J'ai des questions sur les cookies. J'aimerai ...           0
# 18   J'aimerai faire un signalement pour maltraitance           0
# 19     Quel est le numéro du musée de la résistance ?           0
# 20  Ai-je droit à des aides pour la rénovation (is...           0
# 21  Où puis je trouver le le rapport budgétaire 20...           0
# 22  Ma connexion est pourrie. Je voudrais avoir in...           0
# 23  On voudrait adopter un enfant. Qui doit-on con...           0
# 24         Comment bénéficier du pack retour emploi ?           0
# 25                             C'est quoi un cookie ?           0
# 26  Si je veux installer mon entreprise en drome, ...           0
# 27  Quels sont les résultats de conformité du site...           0
# 28  Quels sont les horaires du musée départemental...           0
# 29  Qui dois je contacter pour faire une demande d...           0
# 30     Comment puis-je obtenir la carte top dép'art ?           0
# 31  Existe-t-il des aides pour les frais de cantin...           1
# 32       Où puis-je trouver les logo du département ?           1
# 33                   Je dois faire garder mes enfants           1
# 34  Je voudrais bénéficier de l'accueil familial. ...           1
# 35  Quelles sont les actions en faveur de l'utilis...           1
# 36  Y aura-t-il des options siences dans le collèg...           1
# 37  Combien coûte la téléassistance pour personnes...           1
# 38              Comment obtenir la carte top Départ ?           1
# 39                            Comment obtenir l'APA ?           2
# 40          Qu'est ce que la CLI ? Elle sert à quoi ?           2
# 41  Je voudrais trouver un FabLab pas loin de chez...           2
# 42    Quelles sont les règles du buget participatif ?           2
# 43                              Qu'est-ce-qu'un ENS ?           2
# 44       Je veux trouver un centre de santé sexuelle            2
# 45  Je suis une personne agée. J'ai besoin d'aide ...           3
# 46  A qui puis-je signaler le manque d'accessibili...           3
# 47                 Quelle surface de forêt en drôme ?           4
# 48           Je voudrais consulter le plan foret bois           4
# 49                 De quel college mon fils dépend ?            4
#
#                            label
# 0    [ladrome-page-10901-0.json]
# 1    [ladrome-page-17218-6.json]
# 2    [ladrome-page-95161-0.json]
# 3   [ladrome-page-567239-2.json]
# 4   [ladrome-page-504961-0.json]
# 5   [ladrome-page-541482-1.json]
# 6    [ladrome-page-10868-0.json]
# 7    [ladrome-page-10799-0.json]
# 8   [ladrome-page-547395-2.json]
# 9    [ladrome-page-61260-0.json]
# 10   [ladrome-page-17218-2.json]
# 11   [ladrome-page-10797-0.json]
# 12   [ladrome-page-10763-0.json]
# 13   [ladrome-page-10958-4.json]
# 14   [ladrome-page-10542-0.json]
# 15   [ladrome-page-11012-0.json]
# 16   [ladrome-page-10763-0.json]
# 17  [ladrome-page-581681-9.json]
# 18   [ladrome-page-10799-0.json]
# 19   [ladrome-page-10958-2.json]
# 20   [ladrome-page-10922-0.json]
# 21   [ladrome-page-19110-0.json]
# 22  [ladrome-page-504961-1.json]
# 23   [ladrome-page-10759-0.json]
# 24   [ladrome-page-10700-0.json]
# 25  [ladrome-page-581681-2.json]
# 26   [ladrome-page-10708-0.json]
# 27  [ladrome-page-479533-2.json]
# 28   [ladrome-page-10958-3.json]
# 29   [ladrome-page-13604-0.json]
# 30   [ladrome-page-17218-4.json]
# 31   [ladrome-page-10738-0.json]
# 32   [ladrome-page-62538-0.json]
# 33   [ladrome-page-10763-0.json]
# 34   [ladrome-page-13929-0.json]
# 35   [ladrome-page-10537-0.json]
# 36  [ladrome-page-547344-3.json]
# 37   [ladrome-page-10870-0.json]
# 38   [ladrome-page-17218-4.json]
# 39   [ladrome-page-13604-0.json]
# 40   [ladrome-page-10995-0.json]
# 41  [ladrome-page-504975-0.json]
# 42  [ladrome-page-547395-6.json]
# 43   [ladrome-page-10989-0.json]
# 44   [ladrome-page-13736-0.json]
# 45   [ladrome-page-10899-0.json]
# 46  [ladrome-page-479533-6.json]
# 47   [ladrome-page-10722-0.json]
# 48  [ladrome-page-558957-0.json]
# 49   [ladrome-page-10728-0.json]

# %%
# analyze result of the specific query id
query_id = 35 # the index of the dataframe above
topk = 10

record = result_df.iloc[query_id]
print(record["query"])
for i, r in zip(record["ids"][:topk], record["documents"][:topk]):
    print(f"----------------{i}------------------")
    print(r)
# Out:
# J'aimerai avec des infos sur le sentier du karst
# ----------------11020------------------
# Les stations de la Drôme
#
#
# ----------------61497------------------
# Alpage de Font d’Urle (Vercors)
#
# Grandiose, spectaculaire, sauvage…
# Tels sont les mots qui viennent à l’esprit en évoquant l’alpage de Font d’Urle, ce plateau de 618 hectares propriété du Département de la Drôme depuis 1953.
#
# C’est **un site géologique** passionnant, où se rencontrent des formes spectaculaires liées à l’érosion du calcaire par l’eau, appelées « karst » : roche sculptée en surface, crevasses, puits naturels, grottes, rivières souterraines…
#
# [![](https://www.ladrome.fr/wp-content/uploads/2020/02/ecogarde-matras-004.jpg)](https://www.ladrome.fr/wp-content/uploads/2020/02/ecogarde-matras-004.jpg)
#
# [![](https://www.ladrome.fr/wp-content/uploads/2020/02/font-durle-matras-006.jpg)](https://www.ladrome.fr/wp-content/uploads/2020/02/font-durle-matras-006.jpg)
#
# [![](https://www.ladrome.fr/wp-content/uploads/2020/02/font-durle-matras-001.jpg)](https://www.ladrome.fr/wp-content/uploads/2020/02/font-durle-matras-001.jpg)
#
# Font d’Urle c’est aussi **un alpage** où, depuis des siècles, transhument chaque été chevaux, vaches et moutons.
# Les troupeaux sont parfois protégés par des chiens, notamment des patous.
#
# **Pour votre sécurité et leur tranquillité, les chiens sont interdits sur l’alpage de Font d’Urle, même tenus en laisse, du 1er juin au 30 octobre inclus.
# Respectez les consignes !**
#
# [Consignes de sécurité en présence des troupeaux sur l’alpage de Font d’Urle](https://www.ladrome.fr/wp-content/uploads/2023/01/consignes-securite-troupeaux-font-d-urle.pdf)
#
# ![](https://www.ladrome.fr/wp-content/uploads/2020/02/paysage-font-durle-matras-006.jpg)
#
# Enfin, Font d’Urle possède **une faune et une flore très riche**.
#
# C’est notamment le lieu idéal pour observer les marmottes. Avec un peu de chance, vous pourrez également admirer les vautours fauves planant en bordure des falaises.
#
# Quant aux amoureux de flore sauvage, ils trouvent également leur bonheur : crocus, jonquilles et narcisses, trolles, tulipe sauvage, orchidées ou encore genêt du Dauphiné tapissent l’alpage dès le début du printemps.
#
# ![](https://www.ladrome.fr/wp-content/uploads/2020/02/font-durle-matras-003-1.jpg)
#
# ### Le sentier du karst
#
# Cet itinéraire de 4,6 km permet de cheminer sur un sentier balisé comprenant 10 haltes de découverte (marquées par autant de bornes en pierre) : la glacière, le chaos, les crevasses…
#
# Font d’Urle permet également de pratiquer toute l’année différentes activités de montagne : randonnée, ski alpin et nordique, raquettes, kytesurf, chiens de traîneaux, spéléologie, escalade, équitation…
#
# [Toutes les infos dans nos bons plans sports nature](https://www.ladrome.fr/mon-quotidien/sports/les-bons-plans-sports-nature/)
#
# ### A télécharger
#
# [Guide découverte Le sentier du Karst](https://www.ladrome.fr/wp-content/uploads/2022/12/guide-decouverte-sentier-karst-2021.pdf)
#
# [Règlement intérieur de l’alpage de Font d’Urle](https://www.ladrome.fr/wp-content/uploads/2023/01/reglement-interieur-alpage-font-urle.pdf)
#
# [Arrêté d’interdiction des chiens sur l’alpage de Font d’Urle](https://www.ladrome.fr/wp-content/uploads/2023/01/arrete-interdiction-chiens-font-d-urle.pdf)
#
# [Demande d’autorisation de manifestation sur l’alpage de Font d’Urle](https://www.ladrome.fr/wp-content/uploads/2020/12/4-6-4-2-1-dossier-autorisation-ft-urle.doc)
# ----------------11016------------------
# Les bons plans sports nature
#
# Les sports nature font partie de l’ADN de la Drôme !
#
# Randonnée pédestre, VTT, course d’orientation, escalade, trail, canoë, spéléo, parapente… presque tous les sports de nature peuvent se pratiquer dans la Drôme.
#
# Le Département œuvre au quotidien, en partenariat avec de nombreux acteurs, pour aménager des sites de pratique, les entretenir et concilier les usages.
#
# La Drôme compte aujourd’hui
#
# *   environ 6 000 km de sentiers de randonnée (pédestre, équestre, VTT)
# *   500 km d’itinéraires d’activités aquatiques (canoë kayak)
# *   7 stations hiver/été
# *   5 via ferrata
# *   une vingtaine d’Espaces Sports Orientation
# *   une cinquantaine de sites de vol libre
# *   plus d’une centaine de sites d’escalade
# *   une centaine de cavités de spéléologie…
#
# Retrouvez tous les parcours et sentiers sur l’application mobile La Drôme et laissez-vous guider !
#
# [Accès à l’extranet sport nature](https://collaboratif.ladrome.fr)
# ----------------10974------------------
# Carte collaborative du patrimoine
#
# Sillonnez la carte pour découvrir l’architecture, les paysages, les savoir-faire, les objets et œuvres d’art…
#
# Partez à la découverte de tous ces patrimoines, prestigieux ou plus confidentiels, et apportez votre pierre à l’édifice en devenant contributeur.
# ----------------10966------------------
# Les châteaux de la Drôme
#
# Histoire et culture à Grignan, Suze-la-Rousse, Adhémar (Montélimar)
# ----------------11082------------------
# Je contacte
#
# Les champs finissant par **\*** sont obligatoires
#
# Les informations recueillies à partir de ce formulaire font uniquement l’objet d’un traitement informatique destiné au Département de la Drôme afin de gérer vos demandes.
#
#
#
# Sujet \*
# —Veuillez choisir une option—CultureCandidatures spontanéesDemandes de stage / d'apprentissageSolidaritéRéseau routier départementalEconomie / Agriculture / TourismeCollègiens / EnseignementPersonnes agées / Personnes handicapéesEnfance Famille SantéInsertion RSALogementEnvironnementSportsChâteaux de la DrômeNumériqueTourisme / Stations de montagneService communicationAutre
#
# Vous êtes
# ParticulierAssociationEntreprise
#
# Nom de l'entreprise
#
# Numéro SIRET
#
# Le numéro SIRET est composé de 14 chiffres (Exemple : 01234567890123)
#
# Nom de l'association
#
# Numéro RNA de l'association
#
# Le numéro RNA est composé par un "W" et 9 chiffres (Exemple : W012345678)
#
# Prénom \*
#
# Nom \*
#
# Adresse
#
# Code postal
#
# Ville
#
#
# E-mail \*
#
# Exemple : nom@exemple.fr
#
# Objet
#
# Votre message \*
#
# Joindre un fichier.
# Votre fichier doit être au format JPG, GIF ou PDF et ne doit pas dépasser 2 Mo.
# \* J'ai pris connaissance des [informations relatives aux données personnelles](/donnees-personnelles) et aux [conditions générales d'utilisation](/conditions-generales-dutilisation-du-formulaire-de-contact) concernant les traitements de ce formulaire et j'accepte leur utilisation par le Département de la Drôme
#
#
#
#
#
#
# Si vous souhaitez faire une candidature spontanée ou une demande de stage, merci de vous rendre sur le site [recrutement.ladrome.fr](https://recrutement.ladrome.fr/?page=advertisement) afin que votre dossier soit traité dans les meilleurs délais.
#
# Si vous souhaitez contacter les châteaux de la Drôme, nous vous invitons à visiter leur site internet [chateaux-ladrome.fr](https://www.chateaux-ladrome.fr) ou à les contacter via le [formulaire de contact des châteaux de la Drôme](https://www.chateaux-ladrome.fr/fr/nous-contacter)
#
# Vous pouvez également adresser vos courriers à l’adresse suivante :
#
# **Département de la Drôme**
# 26, avenue du Président Herriot
# 26026 Valence cedex 9
#
# Ou nous contacter au 04 75 79 26 26.
#
# Pour toute question concernant la carte Top Dép’Art : **contactez le 0 800 711 362, appel gratuit du lundi au vendredi de 8h à 20h.**
# ----------------10944------------------
# Le laboratoire départemental
#
#
# ----------------61260------------------
# Forêt de Saoû (vallée de la Drôme)
#
# ### La forêt de Saoû
#
# La forêt et son massif s’étendent sur 2 500 hectares. Véritable écrin naturel, la forêt abrite une faune et une flore remarquables. Le chemin des crêtes permet de rallier les Trois Becs : Rochecourbe, le Signal et le Veyou.
#
# Le massif est aussi réputé auprès des géologues pour être le plus haut synclinal perché d’Europe.
#
# ![](https://www.ladrome.fr/wp-content/uploads/2019/10/4-4-6-8-1-2-8-plan-saou-panneau-vdef-basseresolution-1200x800.jpg)
#
# ![](https://www.ladrome.fr/wp-content/uploads/2019/07/saou-3-1024x681.jpg)
#
# Le synclinal perché de Saoû
#
# ### A télécharger
#
# [Carte Espace Sports d’Orientation Les Sables Blancs à Saoû](https://www.ladrome.fr/wp-content/uploads/2023/01/espace-sports-orienation-sables-blancs-saou.pdf)
#
# [Règlement intérieur de la forêt départementale de Saoû](https://www.ladrome.fr/wp-content/uploads/2023/01/reglement-interieur-foret-saou.pdf)
#
# [Arrêté d’interdiction des chiens sur l’alpage des Trois Becs](https://www.ladrome.fr/wp-content/uploads/2023/01/arrete-interdiction-chiens-alpage-trois-becs.pdf)
#
# [Demande d’autorisation de manifestation en forêt de Saoû](https://www.ladrome.fr/wp-content/uploads/2020/12/4-6-4-2-1-dossier-autorisation-saou.doc)
# ----------------61507------------------
# Serre de l’Âne (Diois)
#
# Découverte en 1977 et reconnue site géologique majeur, la falaise du Serre de l’Âne est située sur la commune de la Charce, dans le Diois.
#
# Elle a enregistré en continu l’histoire de notre planète durant 5 millions d’années, marquant l’articulation entre les périodes du Valanginien (-140 à -134 millions d’années) et du Hauterivien (-134 à -117 millions d’années).
#
# ![](https://www.ladrome.fr/wp-content/uploads/2019/10/serre-ane-large.jpg)
#
# Le Département et la commune ont travaillé pour sa préservation, sa valorisation et son ouverture au public en créant un parcours d’interprétation en 3 stations :
#
# *   La Terrasse : observation du paysage alentour
# *   Le Chemin des temps géologiques : explication du phénomène géologique du Serre de l’Ane
# *   Le Jardin des fossiles : reproductions de fossiles trouvés sur le site et à proximité par les géologues
#
# ![](https://www.ladrome.fr/wp-content/uploads/2019/10/3-large-0.jpg)
#
# ### A télécharger
#
# [Fiche descriptive Serre de l’Âne](https://www.ladrome.fr/wp-content/uploads/2020/02/serredelane-web.pdf)
# ----------------61494------------------
# Plateau d’Ambel (Vercors)
#
# Il étend ses 1 231 hectares au cœur du massif du Vercors et témoigne d’une longue histoire de confrontations entre forces géologiques, climatiques, et humaines.
#
# Une promenade discrète et attentive peut vous réserver de belles surprises : cerfs, chamois, renards, arbres remarquables, gentianes, orchidées…
#
# ![](https://www.ladrome.fr/wp-content/uploads/2019/10/randonnee-plateau-ambel-l--pascale.jpg)
#
# ### A télécharger
#
# [Règlement intérieur du plateau d’Ambel](https://www.ladrome.fr/wp-content/uploads/2020/02/4-4-1-2-3-2011-ri.pdf)
#
# [Règlement d’utilisation des refuges du plateau d’Ambel](https://www.ladrome.fr/wp-content/uploads/2020/02/4-4-1-2-3-2012-arrete-refuges.pdf)
#
# [Arrêté d’interdiction des chiens sur le plateau d’Ambel](https://www.ladrome.fr/wp-content/uploads/2020/02/4-6-4-1-2-5-arrete-chiens-ambel-signe-0.pdf)
#
# [Demande d’autorisation de manifestation sur le plateau d’Ambel](https://www.ladrome.fr/wp-content/uploads/2020/12/4-6-4-2-1-dossier-autorisation-ambel.doc)

# %%
# Store result in new variable for comparison later
result_old_chunks = result_df.copy()

# %% [markdown]
# ### Step 4 : Compare !
# #### Position of the relevant document in the retrieved documents

# %%
new_collection_size = len(result_new_chunks.iloc[0]["ids"])
print(f"Collection size : {new_collection_size}")
result_new_chunks.head(2)
# Out:
# Collection size : 361
#    index                                                ids  \
# 0      0  [ladrome-page-573222-1.json, ladrome-page-1096...
# 1     29  [ladrome-page-62538-0.json, ladrome-page-10728...
#
#                                            distances  \
# 0  [0.575617840095566, 0.6614375114440918, 0.7035...
# 1  [0.6856098959777752, 0.6959853768348694, 0.726...
#
#                                            metadatas  \
# 0  [{'source_file': 'ladrome-page-573222.json'}, ...
# 1  [{'source_file': 'ladrome-page-62538.json'}, {...
#
#                                            documents  \
# 0  [# Le cinéma d’animation dans la Drôme\n### Le...
# 1  [# Charte graphique\nLe logo du Département de...
#
#                                                query  \
# 0  Combien de productions ont déjà bénéficié du f...
# 1       Où puis-je trouver les logo du département ?
#
#                           label  label_rank
# 0  [ladrome-page-573222-1.json]           0
# 1   [ladrome-page-62538-0.json]           0

# %%
old_collection_size = len(result_old_chunks.iloc[0]["ids"])
print(f"Collection size : {old_collection_size}")
result_old_chunks.head(2)
# Out:
# Collection size : 191
#    index                                                ids  \
# 0     39  [ladrome-page-10901.json, ladrome-page-10870.j...
# 1     59  [ladrome-page-17218.json, ladrome-page-10728.j...
#
#                                            distances  \
# 0  [0.7409710884094238, 0.7820833921432495, 0.828...
# 1  [0.7730540462319198, 0.7842181324958801, 0.786...
#
#                                            metadatas  \
# 0  [{'source_file': 'ladrome-page-10901.json'}, {...
# 1  [{'source_file': 'ladrome-page-17218.json'}, {...
#
#                                            documents  \
# 0  [Logement adapté\n\nUn logement inadapté peut ...
# 1  [La carte Top Dép’Art\n\n**Acheter un livre, p...
#
#                                                query  \
# 0  Je voudrais installer un monte escalier mais ç...
# 1  J'ai perdu ma carte top départ, je fais commen...
#
#                          label  label_rank
# 0  [ladrome-page-10901-0.json]           0
# 1  [ladrome-page-17218-6.json]           0

# %%
def get_label_rank_percentage(result_df, collection_size):
    """Get the cumulative percentage of the rank of the relevant document

    Args:
        result_df (pd.DataFrame): the results of the retriever
        collection_size (int): the size of the collection of documents
    """
    chunk_rank_counts = result_df["label_rank"].value_counts().sort_index()
    missing_indexes = [i for i in range(collection_size) if i not in chunk_rank_counts.index]
    chunk_rank_counts = pd.concat(
        [chunk_rank_counts,
        pd.DataFrame([0 for _ in range(len(missing_indexes))],
        index=missing_indexes)]).sort_index()
    chunk_rank_percent = chunk_rank_counts.cumsum().div(len(result_df)).round(3)

    return chunk_rank_percent

# %%
new_chunk_rank_percent = get_label_rank_percentage(result_new_chunks, new_collection_size).rename(columns={0: "New chunks"})
old_chunk_rank_percent = get_label_rank_percentage(result_old_chunks, old_collection_size).rename(columns={0: "Old chunks"})

# %%
# Plot the cumulative percentage of retrieval position
df_to_plot = pd.concat([new_chunk_rank_percent, old_chunk_rank_percent], axis=1)
df_to_plot.plot(xticks=[i for i in df_to_plot.index if i % 10 == 0], rot=90)
# Out:
# <Axes: >

# %% [markdown]
# As we can see, the new chunking method performs better : the position at which the relevant document is retrieved is closer to 0, despite having a greater amount of documents in the collection !
# WARNING : As the queries were built using the new chunks, there might be bias to keep in mind !

# %%
# Zoom on the begining of the curve
df_to_plot[:20].plot(xticks=[i for i in df_to_plot.index[:30] if i % 5 == 0], rot=90)
# Out:
# <Axes: >

# %% [markdown]
# If we zoom in, we actually see that the old chunks perform better in terms of top 1 : in 50% of case, the relevant document is retrieved at index 0. Howerver, the new chunks perfrom better if we llok at top 5 or top 10.

# %% [markdown]
# #### Length of the context depending on amount of chunks selected

# %%
import tiktoken

def get_topks_relevance(result_df, topks=[1,5,10,20]):

    def get_context_length(docs, n_docs):
        return sum([len(tokenizer.encode(doc)) for doc in docs[:n_docs]])

    tokenizer = tiktoken.get_encoding("cl100k_base")
    records = {}
    for topk in topks:
        relevant_is_here = round(len(result_df[result_df["label_rank"] < topk]) / len(result_df) * 100, 1)
        mean_length_of_context = result_df["documents"].apply(get_context_length, args=[topk]).mean().round()
        median_length_of_context = result_df["documents"].apply(get_context_length, args=[topk]).median().round()

        records[topk] = {"relevant_isin_ctx%":relevant_is_here, "mean_token_count_in_ctx": mean_length_of_context, "median_token_count_in_ctx":median_length_of_context}

    return pd.DataFrame.from_records(records)

# %%
print("Values of context length for topk for NEW chunks")
get_topks_relevance(result_new_chunks)
# Out:
# Values of context length for topk for NEW chunks
#                               1       5       10      20
# relevant_isin_ctx%          43.0    65.8    78.5    86.1
# mean_token_count_in_ctx    374.0  1784.0  3733.0  7224.0
# median_token_count_in_ctx  187.0  1492.0  3344.0  6665.0

# %%
print("Values of context length for topk for OLD chunks")
get_topks_relevance(result_old_chunks, topks=[1, 5, 10, 20])
# Out:
# Values of context length for topk for OLD chunks
#                               1       5       10       20
# relevant_isin_ctx%          39.2    63.3    69.6     74.7
# mean_token_count_in_ctx    617.0  2687.0  5333.0  10771.0
# median_token_count_in_ctx  472.0  2331.0  4934.0  10185.0

# %% [markdown]
# ##### Interpretation
# - Relevant_is_ctx% = How many times the relevant document is in the context, if we keep only the top k documents (as a percentage among the queries of the dataset). -> by increasing the amount of documents we keep, we increase the amount the frequency at which the relevant document is in the context
#
# - mean_token_count_in_ctx = The average amount tokens in the context. As we increase the k amount of documents we keep, the length of the context increases. This is not what we want, as higher context length means more superfluous information for the LLM, and more money spent for querying the LLM !
#
# - median_token_count_in_ctx = same as above, but median instead of mean
#
#
# ##### Conclusion
# It seems that the new chunking method present several advantages over the old method:
# - It has better retrieval rates
# - it allows for smaller chunks, resulting in smaller context : on average the token amount in the context is divided by 2. Thus we can hope an increase in performance in terms of response generation by the LLM
# - the retrieval performance of the new chunking method is better, even though the amount of documents is multiplied by 2
#
# ##### Disclaimer
# - Keep in mind that the queries of the test dataset where formulated by using the new chunks. Thus the dataset may be biased toward the new chunks method
# - Some problems needs to be solved : for example with the new chunking method, the text of a part that is outside its subpart is discarded (e.g. the introductions of part) resulting in a loss of information
