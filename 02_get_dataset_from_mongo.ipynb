# %%
import os
from dotenv import load_dotenv
load_dotenv()

from src.data_generators.GetDataFromMongo import GetDataFromMongo

# %%
LLM_APP_ID = "6585977b875bdeef2f737584"

# %%
mongo = GetDataFromMongo(os.getenv("MONGO_CONNECTION_STRING"))
data = mongo(llm_app_id=LLM_APP_ID)
# Out:
# Data will be fetched from ProdSemantics
# Query returned 295 results...
# Formatting chunks...
#  76%|███████▌  | 223/295 [00:38<00:11,  6.36it/s]
# chunk_id '65a68c88a6ed2cba174cceea' did not match any chunk in ProdSemantics.DocumentChunk
#  78%|███████▊  | 229/295 [00:38<00:10,  6.28it/s]
# chunk_id '65a68c88a6ed2cba174cceea' did not match any chunk in ProdSemantics.DocumentChunk
#  82%|████████▏ | 241/295 [00:40<00:08,  6.08it/s]
# chunk_id '65a68c88a6ed2cba174cceea' did not match any chunk in ProdSemantics.DocumentChunk
# chunk_id '65a68c88a6ed2cba174cceea' did not match any chunk in ProdSemantics.DocumentChunk
# 100%|██████████| 295/295 [00:49<00:00,  5.94it/s]

# %%
data[["query", "chunks", "answer"]].sample(20)
# Out:
#                                                  query  \
# 94   j'ai un probleme informatique, pouvez vous m'a...
# 256          comment contacter le service des achats ?
# 135                                Vous avez un zizi ?
# 175  combien d'habitants de la drome sont sous le s...
# 251  Pas d’accès à la’adresse.  :  www.ladrome.fr/c...
# 189  est-ce qu'il y a des aide spour acheter un vél...
# 117                                 quel mois on est ?
# 118                                                APA
# 255              quel est la répartition homme/femme ?
# 199                       qui est le service concerné?
# 34                                             bonjour
# 281      c'est quoi la recette de la quiche lorraine ?
# 208              qui est le président du département ?
# 83                               candidature spontanée
# 221                    comment accéder à drome infos ?
# 65                                              Emploi
# 158                            Tu t'appelles comment ?
# 49         Où puis-je trouver les démarches en ligne ?
# 291                        Quel temps fait-il à Lyon ?
# 71   Obtenir les circuits bons plans vélo numérique...
#
#                                                 chunks  \
# 94   [{'text': 'Les actions en faveur du numérique ...
# 256  [{'text': 'Suivre une demande de contact
#
# Vous...
# 135  [{'text': 'Vivre à domicile
#
# ', '_id': '658569...
# 175  [{'text': 'Avec le maintien d’une enveloppe de...
# 251  [{'text': 'Politique d’accessibilité
# =========...
# 189  [{'text': 'Les aides aux propriétaires
#
# ### Vo...
# 117  [{'text': 'La santé de la femme enceinte
#
# Des ...
# 118  [{'text': 'L’Allocation Personnalisée Autonomi...
# 255  [{'text': 'Santé de la femme enceinte et du no...
# 199  [{'text': 'Le laboratoire départemental
#
# ', '_...
# 34   [{'text': 'Vivre à domicile
#
# ', '_id': '658569...
# 281  [{'text': 'Vivre à domicile
#
# ', '_id': '658569...
# 208  [{'text': 'Le laboratoire départemental
#
# ', '_...
# 83   [{'text': 'Je m’engage
# ===========
#
# *   [](htt...
# 221  [{'text': 'InfoRoute  :
#
# Cette page permet d’...
# 65   [{'text': 'Vivre en établissement
#
# ', '_id': '...
# 158  [{'text': 'Les cantons
#
# ', '_id': '6585694f875...
# 49   [{'text': 'Documents à télécharger
#
# Pour les d...
# 291  [{'text': 'Les stations de la Drôme
#
# ', '_id':...
# 71   [{'text': 'A vélo
#
# Véritable projet de territo...
#
#                                                 answer
# 94   Bien sûr, je suis là pour vous aider ! Pouvez-...
# 256  Pour contacter le service des achats du Départ...
# 135  Je suis un assistant conversationnel et je n'a...
# 175  Je n'ai pas encore la réponse mais j'apprends ...
# 251  Je suis désolé, mais je n'ai pas accès à l'adr...
# 189  Oui, il existe des aides pour l'achat d'un vél...
# 117  Je suis désolé, mais je ne suis pas capable de...
# 118  L'Allocation Personnalisée d'Autonomie (APA) e...
# 255  Je n'ai pas encore la réponse mais j'apprends ...
# 199  Le service concerné dans ce contexte est le se...
# 34   Bonjour ! Comment puis-je vous aider aujourd'h...
# 281  La quiche lorraine est une spécialité culinair...
# 208  Le président du Conseil départemental de la Dr...
# 83   Si vous souhaitez faire une candidature sponta...
# 221  Pour accéder à Drôme Infos, la plateforme en l...
# 65   Le Département de la Drôme est fortement engag...
# 158  Je suis l'Assistant conversationnel Ladrome.fr...
# 49   Pour trouver les démarches en ligne, vous pouv...
# 291  Je n'ai pas encore la réponse mais j'apprends ...
# 71   Je suis désolé, mais je n'ai pas accès aux inf...

# %%
data["answer"].iloc[97]
# Out:
# 'Je suis désolé d\'apprendre que vous rencontrez des difficultés pour vous connecter à votre compte en ligne. Pour résoudre ce problème, je vous recommande de suivre les étapes suivantes :\n\n1. Assurez-vous d\'avoir entré correctement vos identifiants de connexion (nom d\'utilisateur et mot de passe). Vérifiez également que la touche "Verr. Maj." n\'est pas activée, car les mots de passe sont sensibles à la casse.\n\n2. Si vous avez oublié votre mot de passe, vous pouvez généralement réinitialiser votre mot de passe en cliquant sur le lien "Mot de passe oublié" ou "Réinitialiser le mot de passe" sur la page de connexion. Suivez les instructions qui vous seront fournies pour créer un nouveau mot de passe.\n\n3. Si vous continuez à rencontrer des problèmes, je vous recommande de contacter le support technique du site ou de l\'application que vous utilisez pour accéder à votre compte en ligne. Ils pourront vous aider à résoudre le problème spécifique que vous rencontrez.\n\nSi vous avez besoin d\'une assistance supplémentaire, n\'hésitez pas à me le faire savoir.'
