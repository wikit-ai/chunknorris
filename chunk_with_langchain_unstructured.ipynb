# %%
from langchain.document_loaders import UnstructuredFileLoader
from typing import List
from statistics import mean

import pandas as pd

# %%
file = "./data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf"

loader = UnstructuredFileLoader(
    file,
    mode="elements",
    )
loaded_file = loader.load()

# %%
print({f.metadata["category"] for f in loaded_file})
# Out:
# {'ListItem', 'Title', 'UncategorizedText', 'NarrativeText'}

# %%
# Remove uncategorized text (often it is useless, such as headers and footers)
loaded_file = [f for f in loaded_file if f.metadata["category"] != "UncategorizedText"]
# Drop duplicate elements, because they are likely to be headers or footers
idx_of_non_duplicates = pd.DataFrame([f.page_content for f in loaded_file]).drop_duplicates(keep=False).index
loaded_file = [f for i, f in enumerate(loaded_file) if i in idx_of_non_duplicates]
# Remove headers and footers using thresholding
def is_not_header_or_footer(
    element_points:List[List[float]],
    layout_height:float,
    top_threshold:float=.08,
    bottom_threshold:float=.92
    ) -> bool:
    """Compute the y position of the element based on its points.
    If the y position is above the top_threshold or below the bottom threshold
    it returns False (meaning the element might be a header of footer).

    Args:
        element_points (List[List[float]]): The points of the box location of the text. Must be a list of (x,y) coordinates
        layout_height (float): The height of the page.
        top_threshod (float, optional): the threshold below which the text is considered being a header.
            It is relative to the page height (so must be between 0 and 1) Defaults to .1.
        bottom_threshold (float, optional): the threshold above which the text is considered being a footer.
            It is relative to the page height. Defaults to .1.
    """
    y_pos = mean([p[1] for p in element_points])
    return top_threshold*layout_height <= y_pos <= bottom_threshold*layout_height


loaded_file = [
    f for f in loaded_file\
    if is_not_header_or_footer(f.metadata["coordinates"]["points"], f.metadata["coordinates"]["layout_height"])
    ]

# Group elements using the following rules :
## - group titles as long as we do not have a paragraph
## - when we have a paragraphs, merge them with their titles above
## - if we have a new title following paragraph, start a new group
title_goup_idx = 0
prev_was_paragraph = False
for f in loaded_file:
    if f.metadata["category"] == "Title":
        if prev_was_paragraph:
            title_goup_idx += 1
        f.metadata["merging_group"] = title_goup_idx
        prev_was_paragraph = False
    else:
        f.metadata["merging_group"] = title_goup_idx
        prev_was_paragraph = True

chunks = []
for idx in range(title_goup_idx+1):
    new_chunk = [f.page_content for f in loaded_file if f.metadata["merging_group"] == idx]
    chunks.append(new_chunk)

# %%
chunks
# Out:
# [['Pôle QVT-DH 04 mai 2020',
#   'Table des matières',
#   'Accès en mode Web à la plateforme Teams du Conseil Départemental ........................ 4'],
#  ['Planifier une réunion en vidéo-conférence pour une équipe, un canal .......................... 16',
#   'Planifier une vidéo-conférence avec des correspondants isolés .................................... 16',
#   'Pour démarrer une visio-conférence entre tous les membres d’un canal ........................... 20',
#   'Annexe : installer l’application Teams sur un ordinateur du CD 29 ................................ 24',
#   'Document en cours d’élaboration. Si besoin appeler le 4857'],
#  ['Accéder à Teams',
#   "Microsoft Teams est une plateforme collaborative pour le travail d'équipe autour d’Office 365. Vos conversations, fichiers, réunions et applications sont rassemblés dans un seul espace de travail partagé accessible depuis un navigateur (depuis un pc, une tablette, un smartphone)",
#   'Il permet la vidéoconférence, la messagerie instantanée, (le chat) et travail en commun sur des fichiers. Parle de travail en équipe',
#   'On accède à teams soit en mode Web avec les navigateurs Edge ou Chrome uniquement ou en installant une application gratuite dans les autres cas. Certains navigateurs tels qu’Internet Explorer 11, Safari et Firefox prennent en charge Microsoft teams Web App, mais ne prennent pas en charge certaines fonctionnalités d’appel et de réunion. Dans ce cas il sera indispensable d’installer l’application Windows',
#   'Il n’est pas nécessaire d’être sur un ordinateur du Conseil départemental pour vous connecter. Vous accédez à votre compte teams depuis un Mac, une tablette ou un smartphone si vous installez l’application teams correspondante.',
#   'Accès en mode Web à la plateforme Teams du Conseil Départemental',
#   'Teams nécessite un compte Microsoft. Ce compte est mis en place par la DSI'],
#  ['Se connecter : https://office.live.com',
#   'Identifiant : indiquez votre adresse de messagerie',
#   'On vous demande si vous devez rester connecté ; répondre oui'],
#  ['On arrive sur la page d’accueil',
#   'Cliquez sur',
#   'en haut à gauche puis :',
#   'Sélectionnez teams',
#   'Attention ! Vous pouvez avoir un compte Microsoft sans qu’aucune application ne soit accessible. Dans ce cas demandez, leur mise en place par la DSI sous couvert du supérieur hiérarchique (mail : DSIPCA99@finistere.fr )',
#   'A l’ouverture de teams il vous sera demandé d’installer l’application ou d’utiliser l’application Windows. L’application Windows vous facilitera l’utilisation de Teams, notamment au niveau de la connexion. Cette application vous avertira en temps réel des notifications qui vous concernent.',
#   'Attention ! Vous n’êtes pas administrateur de votre poste ! Ne cliquez pas sur télécharger l’application cela ne fonctionnera pas. Une notice d’installation propre au CD29 vous est jointe en annexe',
#   'Nous choisirons dans un premier temps l’application Web'],
#  ['On arrive ici',
#   'La page d’accueil de T eams',
#   '2 équipes : Formations : Conseil Dépt et',
#   'Publication de l’équipe Conseil départemental du Finistère, canal général',
#   'La barre latérale gauche',
#   'Les icônes de la barre latérale gauche donnent accès à différents éléments de l’application',
#   'Affiche vos activités récentes dans les différents canaux dont vous êtes membre',
#   'Le mode conversation dresse la liste de vos messages récents. Vous pouvez parcourir la liste de messages et ouvrir un message pour écrire une réponse, lire une conversation entière, démarrer un appel ou partager un fichier dans une conversation. Vous pouvez commencer une discussion privée ici.',
#   'L’affichage calendrier dresse la liste de vos réunions à venir. Vous pouvez parcourir les réunions à venir, participer à une réunion en ligne ou planifier une réunion. Il n’est pas synchronisé avec votre agenda professionnel',
#   'Donne accès aux équipes et aux canaux dont vous faites partie.',
#   'Dans l’affichage appels, vous pouvez appeler directement vos contacts Vous pouvez également parcourir l’historique de vos appels et consulter votre messagerie vocale. Remarque : La fonction appels n’est disponible que dans certaines régions.',
#   'Pour voir les fichiers partagés par vous ou par d’autres dans vos différents canaux ainsi que ceux stockés dans votre espace One drive.',
#   'Cette icone permet d’utiliser d’autres applications notamment des applications de plateformes collaboratives telles que Zoom dont on parlera plus tard.',
#   'Un peu plus bas l’icône applications permet d’installer les applications utilisées plus haut'],
#  ['Le volet central',
#   'Par défaut l’onglet Équipes est ouvert',
#   'Les équipes',
#   'Les équipes sont des groupes de travail comprenant des agents du CD29 qui travaillent ensemble. Vous voyez les équipes dont vous faites partie.'],
#  ['Le nom de chaque équipe est précédé d’un carré de couleur.',
#   'Dans un premier temps vous apercevez au minimum l’équipe « Conseil départemental du Finistère »',
#   'D’autres équipes peuvent être présentes. Elles ont été créées par vous ou par d’autres agents du CD29 qui vous ont défini comme membre de ces équipes. Les équipes sont publiques ou privées Selon le cas (un cadenas indique leurs statuts)'],
#  ['Sur la page précédente on trouve par exemple l’équipe Formation',
#   'D’autres canaux regrouperont les membres de l’équipe qui travaillent ensemble ou participent à un projet particulier. Dans le groupe formation les agents qui concourent à la formation Teams ont été regroupés dans un canal nommé « formation à Teams »'],
#  ['Le volet princ ipal',
#   'Par défaut il contient l’espace de messagerie instantané qui permet des échanges au sein des équipes ou des canaux. Notez que ces échanges sont appelés publications quand elles concernent les équipes et les canaux et conversations quand elles désignent des échanges entre vous et des collaborateurs que vous avez choisis',
#   'Deux façons de travailler avec T eams :'],
#  ['Le travail en équipe :',
#   'Tout ce que vous faites est visible et accessible par l’équipe (ou par le canal qui est une subdivision de l’équipe)',
#   '- -',
#   'Si vous tenez une conversation, chaque membre du canal peut y participer Si vous tenez une conférence vidéo, chaque membre de l’équipe peut s’inviter Si vous partagez des fichiers, chaque membre du canal pourra les ouvrir et les modifier',
#   'Il va sans dire que l’équipe « Conseil départemental du Finistère » qui regroupe l’ensemble des agents du CD29 sera peu utilisée pour collaborer au niveau d’équipes plus restreintes'],
#  ['Le travail collaboratif de gré à gré :',
#   'Vous invitez une ou plusieurs personnes à chater, à participer à une visio-conférence, ou à partager des fichiers. Vous et vos interlocuteurs êtes les seuls à le savoir et à pouvoir y participer',
#   'A cette fin nous utiliserons le menu conversations situé dans la barre latérale gauche'],
#  ['Créer une équipe',
#   'Dans la partie basse à gauche, l’icône équipes étant sélectionné : cliquez sur Rejoindre ou créer une équipe'],
#  ['Puis Créer une équipe',
#   'Je choisis : « à partir de zéro »',
#   '« Créer à partir de » duplique une équipe existante (avec ses membres)',
#   'Je choisis publique ou privé. Une équipe publique pourra être rejointe par chaque agent du CD29. En général on choisit donc privé'],
#  ['Je choisis le nom de l’équipe',
#   'Puis je clique sur Créer.',
#   'Je peux maintenant ajouter des membres, puis valider',
#   'Une équipe est créée avec un canal général. Ce canal contient tous les membres de l’équipe',
#   'Un clic sur … puis « Gérer l’équipe »nous permettra de personnaliser si besoin les paramétrages de l’équipe',
#   'Différents onglets se présentent'],
#  ['Membre',
#   ': Ajouter ou supprimer des membres',
#   'Demandes en attente : Gérer les demandes d’adhésion'],
#  ['Canaux',
#   ': Création / suppression de canaux',
#   'Analyse',
#   ': Activité de l’équipe',
#   'Applications',
#   ': Application accessible depuis Teams',
#   'Regardons de plus près l’onglet Paramètres',
#   'L’équipe « Démonstration » étant privée le code équipe sera nécessaire aux agents qui veulent rejoindre cette équipe (sauf si le propriétaire de l’équipe ajoute lui-même les agents)'],
#  ['Rejoindre une équipe',
#   'Dans la partie basse à gauche : Rejoindre ou créer une équipe'],
#  ['Vous connaissez le code équipe (voir plus haut)',
#   'Vous n’avez pas le code équipe, faite une recherche',
#   'Vous pouvez taper uniquement la première lettre du nom de l’équipe dans la zone de recherche. Ne seront accessibles que les équipes publiques'],
#  ['Paramétrer une équipe',
#   'Regardons L’équipe Conseil départemental du Finistère : Clic sur les 3 points puis gérer l’équipe'],
#  ['L’onglet membres',
#   'On y trouve (onglet membres) les propriétaires et les membres de cette équipe'],
#  ['L’onglet canaux',
#   'L’onglet canaux montre les canaux de l’équipe Conseil départemental du Finistère, ceux actifs et ceux supprimés'],
#  ['L’onglet analyse', 'L’onglet analyse nous montre l’activité de l’équipe,'],
#  ['L’onglet applications',
#   'L’onglet applications présente les programmes à disposition des membres de l’équipe.',
#   'Par défaut les applications sont les suivantes',
#   'Comme nous ne sommes par propriétaires de l’équipe « Conseil départemental du Finistère » les onglets Demandes en attente et paramètres ne sont pas affichés'],
#  ['Créer un canal',
#   'Comme vu plus haut le canal est un sous ensemble d’une équipe.',
#   'Une équipe peut être constituée d’agents aux métiers et aux préoccupations différentes.',
#   'Au CD 29, je ne connais pas les directives concernant la création des équipes. On peut considérer que la Direction est d’une dimension un peu grande, prenons plutôt l’échelon en dessous : le pôle ou le service. Je prendrai comme exemple le pole QVT-DH',
#   'Je crée donc une équipe QVT et nous allons pouvoir partager des informations, des fichiers, entre tous les agents de pôle. Différentes missions sont effectuées au sein de ce pôle. Celui de la médecine par exemple. Elle concerne les médecins et leur assistantes. Je vais créer un canal « Médecins » : vu son caractère confidentiel je le déclarerai privé. Seuls deux médecins et leurs assistantes y auront accès.',
#   'Chaque semaine a lieu une réunion de pôle. On peut imaginer un canal « Réunions du pôle » où seront téléchargeables tous les documents utiles à ces réunions ; où pourront être élaborés en commun des comptes rendus. Il pourra y être discuté du contenu des prochaines réunions… Ce canal concernant tous les agents du pôle sera public –ce terme s’entend public pour les agents du pôle QVT-',
#   'Des canaux évènementiels pourront être créés pour faciliter le travail en commun (arbre de Noël, sortie annuelle du pôle…)'],
#  ['L’onglet publications',
#   'Si on clique sur le canal général de l’équipe, la page de droite contient des messages système ainsi que les derniers échanges de messagerie instantanée de ce canal (si on est sur l’onglet Publications comme ci-dessous). Si une vidéoconférence est en cours on pourra s’y connecter ici.',
#   'Dans la partie inférieure de l’écran vous pouvez participer à ces échanges qui seront visibles par l’ensemble du personnel. Ce qui, en général, n’est pas souhaité. Nous verrons cela plus tard dans le cercle plus restreint d’un canal que nous aurons créé.'],
#  ['L’onglet Fichiers',
#   'L’onglet Fichiers vous permet de travailler sur des fichiers mis à disposition par d’autres utilisateurs. L’équipe « Conseil départemental » n’est pas le meilleur endroit pour partager des documents car ils sont modifiables par l’ensemble des utilisateurs de cette équipe. On préfèrera en général une équipe plus restreinte',
#   'Pour partager des fichiers vous utiliserez la commande « Charger »',
#   'La commande « Nouveau » vous permettra de créer un document ici (partagé par les membres de l’équipe).'],
#  ['Important :',
#   'Si vous vous ouvrez une application (Word ou Excel par exemple) il ne faut pas utiliser la croix pour revenir à Teams mais utiliser le bouton fermer',
#   'On peut aussi utiliser les flèches de navigation pour faire des allers- retours entre Teams et l’application',
#   'Vous pouvez aussi télécharger les fichiers présents et les copier sur votre disque dur si vous voulez par exemple les imprimer'],
#  ['Planifier une réunion en vidéo-conférence pour une équipe, un canal',
#   'Fonction non utilisable pour l’instant',
#   'Préférez les invitations depuis votre calendrier Outlook en cliquant sur l’icône de Teams',
#   'Planifier une vidéo-conférence avec des correspondants isolés'],
#  ['Possible depuis n’importe quel canal',
#   'Je me positionne sur un canal',
#   'Je clique sur l’icône de la caméra (en bas) dans la partie droite'],
#  ['Puis je clique sur planifier une réunion',
#   'Je mets à jour le titre',
#   'Je mets à jour les horaires',
#   'Je supprime le canal',
#   'Je rajoute des participants ici ou ici (présence obligatoire ou non)'],
#  ['Puis envoyer –en haut à gauche',
#   '(Ajouter une position n’est pas renseigné)',
#   'Les invités vont recevoir un message pour participer à cette réunion',
#   'Inviter des personnes extérieures au Conseil départemental à un tchat ou une vidéo-conférence',
#   'Ils devront utiliser Edge (sous windows10) ou Google Chrome pour utiliser les techniques de visio- conférence',
#   'Les membres extérieurs au CD29 doivent faire partie d’une équipe (créée pour l’occasion si besoin) en tant qu’invités.',
#   'Pour les inscrire il faut créer une équipe puis cliquer sur 3 points à côté du nom de l’équipe puis choisir ajouter un membre'],
#  ['Vous saisissez son adresse mail.',
#   'Teams ajoute l’icône en bleu ci-dessous'],
#  ['Vous cliquez dessus puis sur ajouter',
#   'Les « extérieurs » se comportent maintenant comme les agents du Cd29 mais il faut impérativement les inviter s’ils doivent participer à une discussion ou une vidéo-conférence'],
#  ['La discussion',
#   'Discussion a vec tous les agents d’un canal',
#   'Si vous voulez participer à une discussion positionnez-vous sur le canal contenant les agents concernés.',
#   'Dans l’avant dernière ligne de l’espace principal, saisissez votre message puis en clique t ici pour le valider',
#   'Vous pouvez utilise les icones situés en dessous de la zone de saisie pour :',
#   'Utiliser un traitement de texte',
#   'Définir les options de remise'],
#  ['Joindre un fichier',
#   'Insérer un emoji',
#   'un gif',
#   'ou un autocollant',
#   'Planifier une Réunion',
#   'Pour écrire à un correspondant particulier mettre @nomducorrespondant dans le début du message. Il recevra alors une notification'],
#  ['Discussion privée',
#   'Rendez-vous dans la barre latérale et choisissez l’icône conversation.'],
#  ['Choisissez l’onglet « récente »',
#   'Si votre correspondant n’apparait pas dans la liste positionnez-vous sur l’onglet contacts',
#   'Cliquez sur l’icône ajoutez des personnes puis sélectionnez votre correspondant',
#   'Vous pouvez alors soit lui passer un coup de fil pour qu’il rejoigne votre discussion, soit planifier une réunion pour qu’il reçoive un message lui demandant de rejoindre la discussion en cliquant sur cet icone',
#   'Cet icone n’existe pas pour les discussions de groupe qui sont actives en permanence'],
#  ['Dans une discussion vous pou vez :',
#   'Ajouter un texte mis en forme',
#   'Insérer des emoji, des autocollants'],
#  ['Répondre à un message ancien',
#   'Si vous cliquez sur un message la zone suivante apparait',
#   'Vous voulez alors positionner un icone de commentaire sur ce message'],
#  ['En cliquant sur',
#   'vous pouvez',
#   'Modifier',
#   'Supprimer',
#   'Ecouter les conversations (lecteur immersif)'],
#  ['La Visio conférence',
#   'Pour démarrer une visio-conférence entre membres d’un canal'],
#  ['tous',
#   'les',
#   'Puis rejoindre maintenant',
#   'Vous pourrez alors inviter des participants',
#   'Pour démarrer une con versation privée (hors canal)',
#   'Rendez-vous dans l’espace conversation',
#   'Regarder dans la conversation récente si vous trouvez votre interlocuteur.'],
#  ['Si vous le trouvez, sélectionnez le puis cliquez sur',
#   'Si vous ne trouvez pas votre interlocuteur allez voir dans les contacts ; s’il n’y est pas ajoutez-le',
#   'Quand c’est fait : sélectionnez le puis cliquez sur'],
#  ['Dans une Visio-conférence vous pou vez :',
#   'Cacher le mur derrière vous et mettre un fond proposé par teams (Bluffant)',
#   'Afficher les conversations.',
#   'Si vous êtes l’organisateur d’une réunion vous pouvez aussi déclencher l’enregistrement d’une note de réunion qui sera ensuite accessible dans un nouvel onglet au niveau de votre canal de discussion',
#   'Enregistrer une conférence. Elle sera accessible ensuite à l’aide de l’application STREAM disponible ici'],
#  ['Transférer votre vidéoconférence à quelqu’un d’autre (similaire à un transfert d’appel téléphonique).',
#   'Votre avatar',
#   'Cliquez ici, en haut à droite de votre écran :',
#   'Vous pouvez définir votre disponibilité ici',
#   'Si vous cliquez sur paramètres vous pourrez personnaliser votre application notamment au niveau de la langue utilisée, le démarrage automatique avec Windows (en mode arrière-plan ou non)',
#   'Vous pouvez aussi tester vos matériels audio et vidéo'],
#  ['Communiquer avec l’application Zoom',
#   'Zoom est une plateforme de messagerie instantanée et de vidéo-conférence multiplateforme, basée dans le cloud, et disponible au téléchargement sous forme d’applications, de logiciel PC mais aussi accessible depuis le navigateur web. Même cette application est un peu malmenée actuellement (avril 2020) Pour des raisons de sécurité, zoom n’en reste pas moins incontournable notamment en raison du nombre très important de ses abonnés notamment parmi les partenaires du CD29 (10 millions d’utilisateurs habituels, 200 millions en avril 2020)'],
#  ['Onglet :',
#   'puis',
#   'Il vous faudra ensuite créer un identifiant sous l’application zoom',
#   'Il faudra ensuite au travers de l’application envoyer un mail à votre correspondant',
#   'Annexe : installer l’application T eams sur un ordinateur du CD 29',
#   'Obligatoire si vous êtes en Windows 7',
#   'Si vous êtes sous Windows 10 vous pouvez aussi l’installer pour des raisons de facilité et de rapidité d’accès, ou si Edge n’est pas votre navigateur par défaut.',
#   'Selon le cas il vous sera demandé :',
#   'Vos identifiants de connexion : votre adresse de messagerie sous la forme Prenom.nom@finistère.fr',
#   'Votre mot de passe : celui que vous utilisez pour démarrer votre poste ou pour accéder à la messagerie du CD29 par internet.'],
#  ['Installation :',
#   'Dans le menu démarrer cliquez sur Microsoft System Center puis'],
#  ['Configuration Manager puis sur Centre Logiciel',
#   'L’écran suivant s’ouvre',
#   'Vous pouvez maintenant cliquer sur Microsoft Teams puis suivre les instructions et installer le programme'],
#  ['L’installation crée un icône sur le Bureau',
#   'Lancez l’application',
#   'La première fois il peut vous être demandé vos identifiants de connexion :'],
#  ['Puis']]

# %%
loaded_file
# Out:
# [Document(page_content='Pôle QVT-DH 04 mai 2020', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((344.7, 748.175), (344.7, 764.175), (523.596, 764.175), (523.596, 748.175)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 1, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 0}),
#  Document(page_content='Table des matières', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.82499999999993, 74.02999999999997), (70.82499999999993, 90.02999999999997), (195.86600799999994, 90.02999999999997), (195.86600799999994, 74.02999999999997)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 2, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 0}),
#  Document(page_content='Accès en mode Web à la plateforme Teams du Conseil Départemental ........................ 4', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((99.22499999999991, 139.13999999999987), (99.22499999999991, 150.57999999999993), (527.0659999999999, 150.57999999999993), (527.0659999999999, 139.13999999999987)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 2, 'parent_id': '1bfc387e0a8e8d2b0de3816c391d9339', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 0}),
#  Document(page_content='Planifier une réunion en vidéo-conférence pour une équipe, un canal .......................... 16', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.82500000000005, 613.6600000000001), (70.82500000000005, 625.1), (527.066, 625.1), (527.066, 613.6600000000001)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 2, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 1}),
#  Document(page_content='Planifier une vidéo-conférence avec des correspondants isolés .................................... 16', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.82500000000005, 651.26), (70.82500000000005, 662.7), (527.066, 662.7), (527.066, 651.26)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 2, 'parent_id': '8eac0d99a0459bf4011d5920d878a62c', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 1}),
#  Document(page_content='Pour démarrer une visio-conférence entre tous les membres d’un canal ........................... 20', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((81.82500000000005, 170.95999999999992), (81.82500000000005, 182.39999999999998), (527.066, 182.39999999999998), (527.066, 170.95999999999992)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 3, 'parent_id': '222589fad5d9fab7de34a6d29c9f4c96', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 1}),
#  Document(page_content='Annexe : installer l’application Teams sur un ordinateur du CD 29 ................................ 24', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.82500000000005, 323.18999999999994), (70.82500000000005, 334.62999999999994), (527.0660000000001, 334.62999999999994), (527.0660000000001, 323.18999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 3, 'parent_id': '222589fad5d9fab7de34a6d29c9f4c96', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 1}),
#  Document(page_content='Document en cours d’élaboration. Si besoin appeler le 4857', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.82499999999993, 72.96999999999991), (70.82499999999993, 83.96999999999991), (340.3859999999999, 83.96999999999991), (340.3859999999999, 72.96999999999991)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'parent_id': '627cc85656f3eee70db7227b22524c2b', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 1}),
#  Document(page_content='Accéder à Teams', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((222.88, 97.18999999999994), (222.88, 113.18999999999994), (376.96799999999996, 113.18999999999994), (376.96799999999996, 97.18999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 2}),
#  Document(page_content="Microsoft Teams est une plateforme collaborative pour le travail d'équipe autour d’Office 365. Vos conversations, fichiers, réunions et applications sont rassemblés dans un seul espace de travail partagé accessible depuis un navigateur (depuis un pc, une tablette, un smartphone)", metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.82499999999999, 148.76999999999998), (70.82499999999999, 188.79999999999995), (514.404004, 188.79999999999995), (514.404004, 148.76999999999998)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'parent_id': '9cda5daf091b6e1c8cbf87428ac3f462', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 2}),
#  Document(page_content='Il permet la vidéoconférence, la messagerie instantanée, (le chat) et travail en commun sur des fichiers. Parle de travail en équipe', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.82499999999999, 200.39999999999998), (70.82499999999999, 225.79999999999995), (497.52900299999976, 225.79999999999995), (497.52900299999976, 200.39999999999998)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'parent_id': '9cda5daf091b6e1c8cbf87428ac3f462', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 2}),
#  Document(page_content='On accède à teams soit en mode Web avec les navigateurs Edge ou Chrome uniquement ou en installant une application gratuite dans les autres cas. Certains navigateurs tels qu’Internet Explorer 11, Safari et Firefox prennent en charge Microsoft teams Web App, mais ne prennent pas en charge certaines fonctionnalités d’appel et de réunion. Dans ce cas il sera indispensable d’installer l’application Windows', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.8249999999999, 237.39999999999998), (70.8249999999999, 306.41999999999996), (520.5389999999999, 306.41999999999996), (520.5389999999999, 237.39999999999998)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'parent_id': '9cda5daf091b6e1c8cbf87428ac3f462', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 2}),
#  Document(page_content='Il n’est pas nécessaire d’être sur un ordinateur du Conseil départemental pour vous connecter. Vous accédez à votre compte teams depuis un Mac, une tablette ou un smartphone si vous installez l’application teams correspondante.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.82499999999987, 317.8299999999999), (70.82499999999987, 357.8299999999999), (520.7510029999999, 357.8299999999999), (520.7510029999999, 317.8299999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'parent_id': '9cda5daf091b6e1c8cbf87428ac3f462', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 2}),
#  Document(page_content='Accès en mode Web à la plateforme Teams du Conseil Départemental', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((71.225, 394.61999999999995), (71.225, 406.61999999999995), (472.286, 406.61999999999995), (472.286, 394.61999999999995)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'parent_id': '9cda5daf091b6e1c8cbf87428ac3f462', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 2}),
#  Document(page_content='Teams nécessite un compte Microsoft. Ce compte est mis en place par la DSI', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 416.84999999999997), (70.825, 427.84999999999997), (415.21600299999983, 427.84999999999997), (415.21600299999983, 416.84999999999997)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'parent_id': '9cda5daf091b6e1c8cbf87428ac3f462', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 2}),
#  Document(page_content='Se connecter : https://office.live.com', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 439.24999999999994), (70.825, 450.24999999999994), (239.566, 450.24999999999994), (239.566, 439.24999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 3}),
#  Document(page_content='Identifiant : indiquez votre adresse de messagerie', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 461.84999999999997), (70.825, 472.84999999999997), (299.38599999999997, 472.84999999999997), (299.38599999999997, 461.84999999999997)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 3}),
#  Document(page_content='On vous demande si vous devez rester connecté ; répondre oui', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.82499999999999, 506.87999999999994), (70.82499999999999, 517.8799999999999), (354.786007, 517.8799999999999), (354.786007, 506.87999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'parent_id': '688aecf21ebcce20aa315abd078ba160', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 3}),
#  Document(page_content='On arrive sur la page d’accueil', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 551.8799999999999), (70.825, 562.8799999999999), (207.56599999999997, 562.8799999999999), (207.56599999999997, 551.8799999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 4, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 4}),
#  Document(page_content='Cliquez sur', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 95.57999999999993), (70.825, 106.57999999999993), (126.936, 106.57999999999993), (126.936, 95.57999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 4}),
#  Document(page_content='en haut à gauche puis :', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((177.05, 95.57999999999993), (177.05, 106.57999999999993), (304.986, 106.57999999999993), (304.986, 95.57999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 4}),
#  Document(page_content='Sélectionnez teams', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 140.57999999999993), (70.825, 151.57999999999993), (162.33599999999998, 151.57999999999993), (162.33599999999998, 140.57999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 4}),
#  Document(page_content='Attention ! Vous pouvez avoir un compte Microsoft sans qu’aucune application ne soit accessible. Dans ce cas demandez, leur mise en place par la DSI sous couvert du supérieur hiérarchique (mail : DSIPCA99@finistere.fr )', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 163.0), (70.825, 203.0), (513.436, 203.0), (513.436, 163.0)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'parent_id': '0b0e9cd76fdce09ba88b735d9d4721fb', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 4}),
#  Document(page_content='A l’ouverture de teams il vous sera demandé d’installer l’application ou d’utiliser l’application Windows. L’application Windows vous facilitera l’utilisation de Teams, notamment au niveau de la connexion. Cette application vous avertira en temps réel des notifications qui vous concernent.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 237.0), (70.825, 277.0), (512.316, 277.0), (512.316, 237.0)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'parent_id': '0b0e9cd76fdce09ba88b735d9d4721fb', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 4}),
#  Document(page_content='Attention ! Vous n’êtes pas administrateur de votre poste ! Ne cliquez pas sur télécharger l’application cela ne fonctionnera pas. Une notice d’installation propre au CD29 vous est jointe en annexe', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 289.8299999999999), (70.825, 330.02), (512.836, 330.02), (512.836, 289.8299999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'parent_id': '0b0e9cd76fdce09ba88b735d9d4721fb', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 4}),
#  Document(page_content='Nous choisirons dans un premier temps l’application Web', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 522.8799999999999), (70.825, 533.8799999999999), (333.786, 533.8799999999999), (333.786, 522.8799999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'parent_id': '0b0e9cd76fdce09ba88b735d9d4721fb', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 4}),
#  Document(page_content='On arrive ici', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 545.48), (70.825, 556.48), (129.536, 556.48), (129.536, 545.48)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 5}),
#  Document(page_content='La page d’accueil de T eams', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((176.05, 569.49), (176.05, 585.49), (423.578, 585.49), (423.578, 569.49)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 5}),
#  Document(page_content='2 équipes : Formations : Conseil Dépt et', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((162.05, 632.3), (162.05, 656.6999999999999), (269.06800000000004, 656.6999999999999), (269.06800000000004, 632.3)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 5}),
#  Document(page_content='Publication de l’équipe Conseil départemental du Finistère, canal général', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((388.13, 720.8499999999999), (388.13, 757.0749999999999), (495.32, 757.0749999999999), (495.32, 720.8499999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 5, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 5}),
#  Document(page_content='La barre latérale gauche', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 111.16999999999996), (70.825, 125.16999999999996), (264.562, 125.16999999999996), (264.562, 111.16999999999996)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 5}),
#  Document(page_content='Les icônes de la barre latérale gauche donnent accès à différents éléments de l’application', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 160.79999999999995), (70.825, 171.79999999999995), (477.036, 171.79999999999995), (477.036, 160.79999999999995)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'parent_id': '655860b3b8421de682075dde110170b3', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 5}),
#  Document(page_content='Affiche vos activités récentes dans les différents canaux dont vous êtes membre', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((141.65, 205.79999999999995), (141.65, 216.79999999999995), (501.236, 216.79999999999995), (501.236, 205.79999999999995)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'parent_id': '655860b3b8421de682075dde110170b3', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 5}),
#  Document(page_content='Le mode conversation dresse la liste de vos messages récents. Vous pouvez parcourir la liste de messages et ouvrir un message pour écrire une réponse, lire une conversation entière, démarrer un appel ou partager un fichier dans une conversation. Vous pouvez commencer une discussion privée ici.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((141.65, 225.39999999999998), (141.65, 276.5999999999999), (527.066, 276.5999999999999), (527.066, 225.39999999999998)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'parent_id': '655860b3b8421de682075dde110170b3', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 5}),
#  Document(page_content='L’affichage calendrier dresse la liste de vos réunions à venir. Vous pouvez parcourir les réunions à venir, participer à une réunion en ligne ou planifier une réunion. Il n’est pas synchronisé avec votre agenda professionnel', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((141.65, 297.41999999999996), (141.65, 335.21999999999997), (526.8689999999999, 335.21999999999997), (526.8689999999999, 297.41999999999996)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'parent_id': '655860b3b8421de682075dde110170b3', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 5}),
#  Document(page_content='Donne accès aux équipes et aux canaux dont vous faites partie.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((141.65, 351.21999999999997), (141.65, 362.21999999999997), (426.216, 362.21999999999997), (426.216, 351.21999999999997)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'parent_id': '655860b3b8421de682075dde110170b3', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 5}),
#  Document(page_content='Dans l’affichage appels, vous pouvez appeler directement vos contacts Vous pouvez également parcourir l’historique de vos appels et consulter votre messagerie vocale. Remarque : La fonction appels n’est disponible que dans certaines régions.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((141.65, 393.24999999999994), (141.65, 431.04999999999995), (527.066, 431.04999999999995), (527.066, 393.24999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'parent_id': '655860b3b8421de682075dde110170b3', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 5}),
#  Document(page_content='Pour voir les fichiers partagés par vous ou par d’autres dans vos différents canaux ainsi que ceux stockés dans votre espace One drive.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((141.65, 457.44999999999993), (141.65, 482.04999999999995), (526.9040000000001, 482.04999999999995), (526.9040000000001, 457.44999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'parent_id': '655860b3b8421de682075dde110170b3', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 5}),
#  Document(page_content='Cette icone permet d’utiliser d’autres applications notamment des applications de plateformes collaboratives telles que Zoom dont on parlera plus tard.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((141.65, 508.46999999999997), (141.65, 533.8799999999999), (527.0300000000001, 533.8799999999999), (527.0300000000001, 508.46999999999997)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'parent_id': '655860b3b8421de682075dde110170b3', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 5}),
#  Document(page_content='Un peu plus bas l’icône applications permet d’installer les applications utilisées plus haut', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((141.65, 590.48), (141.65, 615.88), (517.436, 615.88), (517.436, 590.48)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 6, 'parent_id': '655860b3b8421de682075dde110170b3', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 5}),
#  Document(page_content='Le volet central', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 96.76999999999998), (70.825, 110.76999999999998), (196.742, 110.76999999999998), (196.742, 96.76999999999998)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 6}),
#  Document(page_content='Par défaut l’onglet Équipes est ouvert', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 146.38), (70.825, 157.38), (242.166, 157.38), (242.166, 146.38)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 6}),
#  Document(page_content='Les équipes', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((71.225, 171.9699999999999), (71.225, 183.9699999999999), (150.98600000000002, 183.9699999999999), (150.98600000000002, 171.9699999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 6}),
#  Document(page_content='Les équipes sont des groupes de travail comprenant des agents du CD29 qui travaillent ensemble. Vous voyez les équipes dont vous faites partie.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 216.39999999999998), (70.825, 241.79999999999995), (512.835, 241.79999999999995), (512.835, 216.39999999999998)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'parent_id': '743bf4fbf500f38e32bc3077535f1896', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 6}),
#  Document(page_content='Le nom de chaque équipe est précédé d’un carré de couleur.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 253.39999999999998), (70.825, 264.4), (346.786, 264.4), (346.786, 253.39999999999998)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 7}),
#  Document(page_content='Dans un premier temps vous apercevez au minimum l’équipe « Conseil départemental du Finistère »', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 275.8299999999999), (70.825, 286.8299999999999), (523.866, 286.8299999999999), (523.866, 275.8299999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'parent_id': 'e02a8f51c0c399e55cbe50a03deaf687', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 7}),
#  Document(page_content='D’autres équipes peuvent être présentes. Elles ont été créées par vous ou par d’autres agents du CD29 qui vous ont défini comme membre de ces équipes. Les équipes sont publiques ou privées Selon le cas (un cadenas indique leurs statuts)', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 298.41999999999996), (70.825, 338.41999999999996), (506.0609999999998, 338.41999999999996), (506.0609999999998, 298.41999999999996)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'parent_id': 'e02a8f51c0c399e55cbe50a03deaf687', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 7}),
#  Document(page_content='Sur la page précédente on trouve par exemple l’équipe Formation', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 349.81999999999994), (70.825, 360.81999999999994), (369.216, 360.81999999999994), (369.216, 349.81999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 8}),
#  Document(page_content='D’autres canaux regrouperont les membres de l’équipe qui travaillent ensemble ou participent à un projet particulier. Dans le groupe formation les agents qui concourent à la formation Teams ont été regroupés dans un canal nommé « formation à Teams »', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 434.44999999999993), (70.825, 474.44999999999993), (519.5699999999998, 474.44999999999993), (519.5699999999998, 434.44999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'parent_id': '3593c5843faf39ac29d9cee0f606411f', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 8}),
#  Document(page_content='Le volet princ ipal', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 569.0699999999999), (70.825, 583.0699999999999), (211.572, 583.0699999999999), (211.572, 569.0699999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 9}),
#  Document(page_content='Par défaut il contient l’espace de messagerie instantané qui permet des échanges au sein des équipes ou des canaux. Notez que ces échanges sont appelés publications quand elles concernent les équipes et les canaux et conversations quand elles désignent des échanges entre vous et des collaborateurs que vous avez choisis', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 618.6999999999999), (70.825, 673.3), (503.634, 673.3), (503.634, 618.6999999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 7, 'parent_id': '869477580ff89ff6e106a55df7a53e56', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 9}),
#  Document(page_content='Deux façons de travailler avec T eams :', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((127.65, 74.57999999999993), (127.65, 90.57999999999993), (477.798, 90.57999999999993), (477.798, 74.57999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 8, 'parent_id': 'f2e122bbbf7826a0c3f1ba3164feb062', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 9}),
#  Document(page_content='Le travail en équipe :', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((71.225, 126.74999999999989), (71.225, 138.9799999999999), (195.93599999999998, 138.9799999999999), (195.93599999999998, 126.74999999999989)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 8, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 10}),
#  Document(page_content='Tout ce que vous faites est visible et accessible par l’équipe (ou par le canal qui est une subdivision de l’équipe)', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 173.19999999999993), (70.825, 198.79999999999995), (514.054, 198.79999999999995), (514.054, 173.19999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 8, 'parent_id': '02ec7be1c666d1dbf418cf8ce73574d9', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 10}),
#  Document(page_content='- -', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((88.825, 209.75999999999988), (88.825, 250.19999999999993), (95.283, 250.19999999999993), (95.283, 209.75999999999988)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 8, 'parent_id': '02ec7be1c666d1dbf418cf8ce73574d9', 'filetype': 'application/pdf', 'category': 'ListItem', 'merging_group': 10}),
#  Document(page_content='Si vous tenez une conversation, chaque membre du canal peut y participer Si vous tenez une conférence vidéo, chaque membre de l’équipe peut s’inviter Si vous partagez des fichiers, chaque membre du canal pourra les ouvrir et les modifier', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((106.83, 210.19999999999993), (106.83, 250.19999999999993), (497.036, 250.19999999999993), (497.036, 210.19999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 8, 'parent_id': '02ec7be1c666d1dbf418cf8ce73574d9', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 10}),
#  Document(page_content='Il va sans dire que l’équipe « Conseil départemental du Finistère » qui regroupe l’ensemble des agents du CD29 sera peu utilisée pour collaborer au niveau d’équipes plus restreintes', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 284.2299999999999), (70.825, 309.63), (497.836, 309.63), (497.836, 284.2299999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 8, 'parent_id': '02ec7be1c666d1dbf418cf8ce73574d9', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 10}),
#  Document(page_content='Le travail collaboratif de gré à gré :', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((71.225, 343.5999999999999), (71.225, 355.8299999999999), (274.156, 355.8299999999999), (274.156, 343.5999999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 8, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 11}),
#  Document(page_content='Vous invitez une ou plusieurs personnes à chater, à participer à une visio-conférence, ou à partager des fichiers. Vous et vos interlocuteurs êtes les seuls à le savoir et à pouvoir y participer', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 390.24999999999994), (70.825, 430.24999999999994), (454.194, 430.24999999999994), (454.194, 390.24999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 8, 'parent_id': '5199e630d45f5a909f3f292f246a599d', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 11}),
#  Document(page_content='A cette fin nous utiliserons le menu conversations situé dans la barre latérale gauche', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 441.65), (70.825, 452.65), (456.63599999999997, 452.65), (456.63599999999997, 441.65)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 8, 'parent_id': '5199e630d45f5a909f3f292f246a599d', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 11}),
#  Document(page_content='Créer une équipe', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((222.68, 97.18999999999994), (222.68, 113.18999999999994), (377.168, 113.18999999999994), (377.168, 97.18999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 9, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 12}),
#  Document(page_content='Dans la partie basse à gauche, l’icône équipes étant sélectionné : cliquez sur Rejoindre ou créer une équipe', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 148.76999999999998), (70.825, 174.39999999999998), (362.816, 174.39999999999998), (362.816, 148.76999999999998)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 9, 'parent_id': 'e0f3e018a83a4df068150058f1cb321b', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 12}),
# ...
#  Document(page_content='Communiquer avec l’application Zoom', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((129.45, 101.18999999999994), (129.45, 117.18999999999994), (470.39799999999997, 117.18999999999994), (470.39799999999997, 101.18999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 23, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 46}),
#  Document(page_content='Zoom est une plateforme de messagerie instantanée et de vidéo-conférence multiplateforme, basée dans le cloud, et disponible au téléchargement sous forme d’applications, de logiciel PC mais aussi accessible depuis le navigateur web. Même cette application est un peu malmenée actuellement (avril 2020) Pour des raisons de sécurité, zoom n’en reste pas moins incontournable notamment en raison du nombre très important de ses abonnés notamment parmi les partenaires du CD29 (10 millions d’utilisateurs habituels, 200 millions en avril 2020)', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 152.76999999999998), (70.825, 236.39999999999998), (522.295, 236.39999999999998), (522.295, 152.76999999999998)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 23, 'parent_id': 'ccb4655a176ce4bc7f6fedc1603abac6', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 46}),
#  Document(page_content='Onglet :', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 292.8299999999999), (70.825, 303.8299999999999), (111.10600000000001, 303.8299999999999), (111.10600000000001, 292.8299999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 23, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 47}),
#  Document(page_content='puis', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((212.48, 292.8299999999999), (212.48, 303.8299999999999), (233.566, 303.8299999999999), (233.566, 292.8299999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 23, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 47}),
#  Document(page_content='Il vous faudra ensuite créer un identifiant sous l’application zoom', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 427.84999999999997), (70.825, 438.84999999999997), (365.206, 438.84999999999997), (365.206, 427.84999999999997)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 23, 'parent_id': '4825482baab0ea710df72a5409744d8e', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 47}),
#  Document(page_content='Il faudra ensuite au travers de l’application envoyer un mail à votre correspondant', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 450.24999999999994), (70.825, 461.24999999999994), (441.236, 461.24999999999994), (441.236, 450.24999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 23, 'parent_id': '4825482baab0ea710df72a5409744d8e', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 47}),
#  Document(page_content='Annexe : installer l’application T eams sur un ordinateur du CD 29', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((100.82, 96.99000000000001), (100.82, 132.77999999999997), (498.82599999999996, 132.77999999999997), (498.82599999999996, 96.99000000000001)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 24, 'parent_id': 'd909bc1fa542b9fe07957f86cc2ae533', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 47}),
#  Document(page_content='Obligatoire si vous êtes en Windows 7', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 168.79999999999995), (70.825, 179.79999999999995), (250.36599999999999, 179.79999999999995), (250.36599999999999, 168.79999999999995)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 24, 'parent_id': 'd909bc1fa542b9fe07957f86cc2ae533', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 47}),
#  Document(page_content='Si vous êtes sous Windows 10 vous pouvez aussi l’installer pour des raisons de facilité et de rapidité d’accès, ou si Edge n’est pas votre navigateur par défaut.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 191.19999999999993), (70.825, 216.79999999999995), (512.6619999999996, 216.79999999999995), (512.6619999999996, 191.19999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 24, 'parent_id': 'd909bc1fa542b9fe07957f86cc2ae533', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 47}),
#  Document(page_content='Selon le cas il vous sera demandé :', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 265.19999999999993), (70.825, 276.19999999999993), (227.566, 276.19999999999993), (227.566, 265.19999999999993)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 24, 'parent_id': 'd909bc1fa542b9fe07957f86cc2ae533', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 47}),
#  Document(page_content='Vos identifiants de connexion : votre adresse de messagerie sous la forme Prenom.nom@finistère.fr', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 287.63), (70.825, 313.2299999999999), (409.01399999999995, 313.2299999999999), (409.01399999999995, 287.63)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 24, 'parent_id': 'd909bc1fa542b9fe07957f86cc2ae533', 'filetype': 'application/pdf', 'category': 'ListItem', 'merging_group': 47}),
#  Document(page_content='Votre mot de passe : celui que vous utilisez pour démarrer votre poste ou pour accéder à la messagerie du CD29 par internet.', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 324.6299999999999), (70.825, 350.22999999999996), (487.212, 350.22999999999996), (487.212, 324.6299999999999)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 24, 'parent_id': 'd909bc1fa542b9fe07957f86cc2ae533', 'filetype': 'application/pdf', 'category': 'ListItem', 'merging_group': 47}),
#  Document(page_content='Installation :', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 384.79999999999995), (70.825, 398.79999999999995), (146.136, 398.79999999999995), (146.136, 384.79999999999995)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 24, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 48}),
#  Document(page_content='Dans le menu démarrer cliquez sur Microsoft System Center puis', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 410.65), (70.825, 421.65), (427.416, 421.65), (427.416, 410.65)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 24, 'parent_id': '9b2c4f91cf802621314fc4a7875b8a8e', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 48}),
#  Document(page_content='Configuration Manager puis sur Centre Logiciel', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 433.04999999999995), (70.825, 444.04999999999995), (288.786, 444.04999999999995), (288.786, 433.04999999999995)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 24, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 49}),
#  Document(page_content='L’écran suivant s’ouvre', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 72.96999999999991), (70.825, 83.96999999999991), (175.736, 83.96999999999991), (175.736, 72.96999999999991)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 25, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 49}),
#  Document(page_content='Vous pouvez maintenant cliquer sur Microsoft Teams puis suivre les instructions et installer le programme', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 339.81999999999994), (70.825, 365.22999999999996), (492.14399999999995, 365.22999999999996), (492.14399999999995, 339.81999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 25, 'parent_id': 'ed004ac4612b3ef63cd23b708dd0ea2e', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 49}),
#  Document(page_content='L’installation crée un icône sur le Bureau', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 421.65), (70.825, 432.65), (254.36599999999999, 432.65), (254.36599999999999, 421.65)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 25, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 50}),
#  Document(page_content='Lancez l’application', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 444.24999999999994), (70.825, 455.24999999999994), (163.33599999999998, 455.24999999999994), (163.33599999999998, 444.24999999999994)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 25, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 50}),
#  Document(page_content='La première fois il peut vous être demandé vos identifiants de connexion :', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((70.825, 466.65), (70.825, 477.65), (404.006, 477.65), (404.006, 466.65)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 25, 'parent_id': '933fb329da4f663df4e25c3620bac6da', 'filetype': 'application/pdf', 'category': 'NarrativeText', 'merging_group': 50}),
#  Document(page_content='Puis', metadata={'source': './data/raw/1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'coordinates': {'points': ((283.3, 601.68), (283.3, 612.68), (306.586, 612.68), (306.586, 601.68)), 'system': 'PixelSpace', 'layout_width': 595.4, 'layout_height': 841.8}, 'file_directory': './data/raw', 'filename': '1701963097.697041-Prise en main et installation de Microsoft Teams.pdf', 'languages': ['eng'], 'last_modified': '2023-12-14T16:43:24', 'page_number': 25, 'filetype': 'application/pdf', 'category': 'Title', 'merging_group': 51})]
